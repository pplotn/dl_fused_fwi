# %% [markdown]
# # FWI on field data (CGG Broadseis)
#
# by Oleg Ovcharenko
#
# oleg.ovcharenko@kaust.edu.sa
#
# KAUST, 2021

# %%
import os
import sys
#api._cmd('conda activate torch2')
print(f'Python: {sys.prefix}')
import copy
from glob import glob
# import glob
import numpy as np
import importlib
import multiprocessing
import segyio
from scipy import signal, ndimage
from natsort import natsorted
from skimage.transform import rescale, resize
# append path with actual source files to sys.path
sys.path.append(os.path.abspath('../codes_server'))
sys.path.append(os.path.abspath('./utils'))
from utils import shared as sd
from utils import loaders as ld
from utils import vis
from IPython.display import clear_output
from F_utils import *
from F_fwi import *
import pyapi_denise_pavel as api
api._cmd('source /home/plotnips/Madagascar/share/madagascar/etc/env.sh')
api._cmd('source ~/.bashrc')
# create_sbatch_file_for_fwi_folder('./for_pasha/out_for_pasha/fwi_full_spectrum_vanilla')
# results_path='./out_for_pasha/fwi_full_spectrum'
# os.system(f"rm -r {results_path}")
print(filter_seismic_data)
d=api.Denise('/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master',verbose=1)
print(d.get_shots_from_datadir)
print(d.get_shots_from_directory)
print(sys.path)
import nest_asyncio
nest_asyncio.apply()
# Out:
# Python: /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env
# <function filter_seismic_data at 0x14e9508ae6a8>
# Init Python 3 API for Denise-Black-Edition.
# Check binary in /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/bin/denise
# Parse /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/par/DENISE_marm_OBC.inp
# Current directory is /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha
# Init paths at ./outputs/
# <bound method Denise.get_shots_from_datadir of DENISE-Black-Edition:
# 	/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master
# Save folder:
# 	./outputs/
# Run .help() for more details>
# <bound method Denise.get_shots_from_directory of DENISE-Black-Edition:
# 	/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master
# Save folder:
# 	./outputs/
# Run .help() for more details>
# ['', '/home/plotnips/Madagascar/lib/python3.7/site-packages', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env/lib/python36.zip', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env/lib/python3.6', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env/lib/python3.6/lib-dynload', '/usr/lib/python3.6', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env/lib/python3.6/site-packages', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env/lib/python3.6/site-packages/IPython/extensions', '/home/plotnips/.ipython', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/codes_server', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/utils', '../', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master', './for_pasha']

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# mpl.rcParams['figure.dpi']= 100
fontsize = 10
params = {
    # 'text.latex.preamble': ['\\usepackage{gensymb}'],
    # 'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'figure.dpi' : 300,
    # 'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize':fontsize,  # fontsize for x and y labels (was 10)
    'axes.titlesize':fontsize,
    'font.size':fontsize,  # was 10
    'legend.fontsize': fontsize,  # was 10
    'xtick.labelsize':fontsize,
    'ytick.labelsize':fontsize,
    # 'text.usetex': True,
    # 'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
mpl.rcParams.update(params)

# %% [markdown]
# # Init Denise API

# %%
root_fwi = './out_for_pasha/'
denise_root = '../'
d = api.Denise(denise_root, verbose=0)
d.save_folder = root_fwi
d.set_paths()
def divmax(x): return x / np.max(np.abs(x))
# Out:
# Init Python 3 API for Denise-Black-Edition.
# Check binary in ../bin/denise

# %%
print(os.getcwd())
# denise_dir='../fwi/cgg_real_data/cnn_14_1/fld'
denise_dir='/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/fwi/cgg_real_data/cnn_14_1/model__cgg_lin_vp_long/fld'
shots_field,filenames_field=d.get_shots_from_directory(os.path.join(denise_dir,'su'),keys=['_p'],return_filenames=True)
shots_modelled,filenames_modelled=d.get_shots_from_directory(os.path.join(denise_dir,'su_modelled'),keys=['_p'],return_filenames=True)
# Out:
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha

# %%
for ishot in [13, 65]:
    print(ishot)
    shot_s = divmax(shots_modelled[ishot])
    shot_f = divmax(shots_field[ishot])
    # shot_f = divmax(shots_field[ishot, :, ::d.NDT])
#     vis.plot_shot(np.concatenate([np.flip(shot_s, 0), shot_f], axis=0), pclip=0.05)
    vis.plot_compare_stripes(shot_s, shot_f, pclip=0.0125, colorbar=False, dt=0.002, dx=25)
# Out:
# 13
# 65

# %%
print(os.getcwd())
print(os.listdir('../fwi/cgg_real_data'))
# shots,filenames=d.get_shots_from_directory('../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su',keys=['_p'],return_filenames=True)
shots,filenames=d.get_shots_from_directory('/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/out_for_pasha/fwi_full_spectrum/fld/su',keys=['_p'],return_filenames=True)
shots=shots[0:2]
filenames=filenames[0:2]
print(filenames)
for shot,filename in zip(shots,filenames):
    print(filename)
    plot_shot(shot,pclip=0.05,folder_path='./pictures_for_check2',file_path=filename.split('/')[-1]+'.png',show=0)
# Out:
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha
# ['fwi_56_strategy_l5multi_cnn_13_special_weight_235_0_model__Marmousi_1d_lin_300_f_z_1', 'cnn_14_1', '23200982_fwi_56_strategy_l5multi_cnn_13_special_weight_235_1_model__cgg_lin_vp_long_300_f_z_stage1_model__cgg_lin_vp_long.out', 'fwi_50_strategy_l5', 'fwi_48_strategy_l5_weight_1500_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_235_0_model__Marmousi_1d_lin_300_f_z_stage2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_stage1', 'fwi_56_strategy_l2_del_low_weight_147_5hz_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_2', 'fwi_35_strategy_l5_weight_1351_1', 'fwi_51_strategy_l2_weight_1500_0', 'fwi_47_strategy_l5_weight_1351_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_1_model___cgg_lin_vp_long_300_f_z_stage2', 'fwi_48_strategy_l2_weight_1500_0', 'fwi_50_strategy_l2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_235_1_model___cgg_lin_vp_long_300_f_z_stage1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Overthrust_1d_lin_300_f_z_stage0', 'fwi_47_strategy_l5_weight_1500_2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_4', 'fwi_44_strategy_l2_weight_1351_0_model__cgg_lin_vp_long', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_5', 'fwi_49_strategy_l2_weight_1500_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Overthrust_1d_lin_300_f_z_stage3', 'fwi_35_strategy_0', 'fwi_43_strategy_weight_1351_0', 'fwi_48_strategy_l5_weight_1500_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_3', 'fwi_56_strategy_l5_del_low_weight_1500_5hz_0', 'fwi_45_strategy_l5_weight_1351_0_model__cgg_lin_vp_long', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Marmousi_1d_lin_300_f_z_1', 'fwi_35_strategy_l2_weight_1351_2', 'cnn_13', 'fwi_34_strategy_0', 'fwi_48_strategy_l2_weight_1500_1', 'fwi_49_strategy_l5_weight_1500_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_stage', 'fwi_56_strategy_l2', 'fwi_50_strategy_l5_weight_1500_0', 'fwi_56_strategy_l2_del_low_weight_675_5hz_0', 'fwi_35_strategy_l2_weight_1351_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Marmousi_1d_lin_300_f_z_2', 'fwi_49_strategy_l5_weight_1500_0', 'fwi_47_strategy_l2_weight_1351_1', 'fwi_36_strategy_0', 'fwi_51_strategy_l5_weight_1500_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_235_0_model__Overthrust_1d_lin_300_f_z_stage3', 'fwi_35_strategy_l5_weight_1351_0', 'fwi_35_strategy_l2_weight_1351_1', 'fwi_45_strategy_l2_weight_1351_0_model__cgg_lin_vp_long', 'cnn_14', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Marmousi_1d_lin_300_f_z_stage2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_stage0', 'fwi_60_strategy_fullband_l2', 'fwi_50_strategy_l2_weight_1500_0', 'fwi_47_strategy_l5_weight_1351_1', 'fwi_56_strategy_special_l2_del_low_gen__5hz_0', 'fwi_47_strategy_l5_weight_1401_0', 'fwi_47_strategy_l2_weight_1351_0', 'fwi_49_strategy_l2_weight_1500_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_6', 'fwi_56_strategy_l2_del_low_gen__5hz_1', 'fwi_47_strategy_l5_weight_1400_0', 'fwi_50_strategy_l5_weight_1500_1', 'fwi_56_strategy_l5_del_low_weight_574_5hz_0', 'cnn_13_11']
# ['/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/out_for_pasha/fwi_full_spectrum/fld/su/seis_p.su.shot1', '/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/out_for_pasha/fwi_full_spectrum/fld/su/seis_p.su.shot2']
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/out_for_pasha/fwi_full_spectrum/fld/su/seis_p.su.shot1
# save to ./pictures_for_check2/seis_p.su.shot1.png
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/out_for_pasha/fwi_full_spectrum/fld/su/seis_p.su.shot2
# save to ./pictures_for_check2/seis_p.su.shot2.png

# %%
print(os.getcwd())
print(os.listdir('../fwi/cgg_real_data'))
shots,filenames=d.get_shots_from_directory('../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su',keys=['_p'],return_filenames=True)
# shots=shots[::20]
# filenames=filenames[::20]
shots=shots[0:10]
filenames=filenames[0:10]
print(filenames)
for shot,filename in zip(shots,filenames):
    print(filename)
    plot_shot(shot,pclip=0.05,folder_path='./pictures_for_check2',file_path=filename.split('/')[-1]+'.png',show=0)
# Out:
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha
# ['fwi_56_strategy_l5multi_cnn_13_special_weight_235_0_model__Marmousi_1d_lin_300_f_z_1', 'cnn_14_1', '23200982_fwi_56_strategy_l5multi_cnn_13_special_weight_235_1_model__cgg_lin_vp_long_300_f_z_stage1_model__cgg_lin_vp_long.out', 'fwi_50_strategy_l5', 'fwi_48_strategy_l5_weight_1500_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_235_0_model__Marmousi_1d_lin_300_f_z_stage2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_stage1', 'fwi_56_strategy_l2_del_low_weight_147_5hz_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_2', 'fwi_35_strategy_l5_weight_1351_1', 'fwi_51_strategy_l2_weight_1500_0', 'fwi_47_strategy_l5_weight_1351_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_1_model___cgg_lin_vp_long_300_f_z_stage2', 'fwi_48_strategy_l2_weight_1500_0', 'fwi_50_strategy_l2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_235_1_model___cgg_lin_vp_long_300_f_z_stage1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Overthrust_1d_lin_300_f_z_stage0', 'fwi_47_strategy_l5_weight_1500_2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_4', 'fwi_44_strategy_l2_weight_1351_0_model__cgg_lin_vp_long', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_5', 'fwi_49_strategy_l2_weight_1500_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Overthrust_1d_lin_300_f_z_stage3', 'fwi_35_strategy_0', 'fwi_43_strategy_weight_1351_0', 'fwi_48_strategy_l5_weight_1500_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_3', 'fwi_56_strategy_l5_del_low_weight_1500_5hz_0', 'fwi_45_strategy_l5_weight_1351_0_model__cgg_lin_vp_long', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Marmousi_1d_lin_300_f_z_1', 'fwi_35_strategy_l2_weight_1351_2', 'cnn_13', 'fwi_34_strategy_0', 'fwi_48_strategy_l2_weight_1500_1', 'fwi_49_strategy_l5_weight_1500_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_stage', 'fwi_56_strategy_l2', 'fwi_50_strategy_l5_weight_1500_0', 'fwi_56_strategy_l2_del_low_weight_675_5hz_0', 'fwi_35_strategy_l2_weight_1351_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Marmousi_1d_lin_300_f_z_2', 'fwi_49_strategy_l5_weight_1500_0', 'fwi_47_strategy_l2_weight_1351_1', 'fwi_36_strategy_0', 'fwi_51_strategy_l5_weight_1500_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_1', 'fwi_56_strategy_l5multi_cnn_13_special_weight_235_0_model__Overthrust_1d_lin_300_f_z_stage3', 'fwi_35_strategy_l5_weight_1351_0', 'fwi_35_strategy_l2_weight_1351_1', 'fwi_45_strategy_l2_weight_1351_0_model__cgg_lin_vp_long', 'cnn_14', 'fwi_56_strategy_l5multi_cnn_13_special_weight_236_0_model__Marmousi_1d_lin_300_f_z_stage2', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_stage0', 'fwi_60_strategy_fullband_l2', 'fwi_50_strategy_l2_weight_1500_0', 'fwi_47_strategy_l5_weight_1351_1', 'fwi_56_strategy_special_l2_del_low_gen__5hz_0', 'fwi_47_strategy_l5_weight_1401_0', 'fwi_47_strategy_l2_weight_1351_0', 'fwi_49_strategy_l2_weight_1500_0', 'fwi_56_strategy_l5multi_cnn_13_special_weight_237_0_model__Marmousi_1d_lin_300_f_z_6', 'fwi_56_strategy_l2_del_low_gen__5hz_1', 'fwi_47_strategy_l5_weight_1400_0', 'fwi_50_strategy_l5_weight_1500_1', 'fwi_56_strategy_l5_del_low_weight_574_5hz_0', 'cnn_13_11']
# ['../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot1', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot1.it1', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot2', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot3', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot4', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot5', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot6', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot7', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot8', '../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot9']
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot1
# save to ./pictures_for_check2/seis_p.su.shot1.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot1.it1
# save to ./pictures_for_check2/seis_p.su.shot1.it1.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot2
# save to ./pictures_for_check2/seis_p.su.shot2.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot3
# save to ./pictures_for_check2/seis_p.su.shot3.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot4
# save to ./pictures_for_check2/seis_p.su.shot4.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot5
# save to ./pictures_for_check2/seis_p.su.shot5.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot6
# save to ./pictures_for_check2/seis_p.su.shot6.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot7
# save to ./pictures_for_check2/seis_p.su.shot7.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot8
# save to ./pictures_for_check2/seis_p.su.shot8.png
# ../fwi/cgg_real_data/cnn_13_11/model__cgg_tomo_long1/fld/su/seis_p.su.shot9
# save to ./pictures_for_check2/seis_p.su.shot9.png

# %% [markdown]
# # Get acquitision details

# %%
shot_id_min = 60
n_selected_shots = 80
njump_src = 8
shot_id_max = shot_id_min + (n_selected_shots-1) * njump_src

# %%
# %run ./fwi_shared_check_check_water_bottom.ipynb
# fwi_shared_check_check_water_bottom
# Out:
# 95/95
# Before prep:	(95, 648, 3526)
# Data cube:	(95, 324, 3000)
# Extended cube:	(95, 324, 3100)
# [95, 324, 3050] (95, 324, 3000)
# [95, 324, 3150] (95, 324, 3100)
# 25.0
# Assume even average spacing between sources
#  150.0 m ~ 6 grid nodes
# First source:	375.0 m
# Last source:	14450.0 m
# 150.0
# name:
# x	(95,):	min: 375.0	max: 14475.0
# y	(95,):	min: 50.0	max: 50.0
# wavelets:	None
# z	(95,):	min: 0.0	max: 0.0
# nshot:	95
# td	(95,):	min: 0.0	max: 0.0
# fc	(95,):	min: 8.0	max: 8.0
# amp	(95,):	min: 1.0	max: 1.0
# angle	(95,):	min: 0.0	max: 0.0
# QUELLTYPB:	1
# src_type	(95,):	min: 1.0	max: 1.0
# drec:	25.0 m
# x	(324,):	min: 525.0	max: 8600.0
# y	(324,):	min: 100.0	max: 100.0
# many:	[x	(324,):	min: 525.0	max: 8600.0
# y	(324,):	min: 100.0	max: 100.0
# name:	]
# x	(324,):	min: 525.0	max: 8600.0
# y	(324,):	min: 100.0	max: 100.0
# many:	[x	(324,):	min: 525.0	max: 8600.0
# y	(324,):	min: 100.0	max: 100.0
# name:	]
# (152, 600)
# (152, 600)
# (152, 500)
# 12500.0

# %%
print(len(data_p))
print(data_p[0].shape)
# print(data_p[0,...].shape())
# Out:
# 95
# (324, 3000)

# %%
root_su_field = os.path.join(d._root_su, 'field/'); 
d.SEIS_FILE_P=root_su_field
print(data_p.shape)
data_p_backup = data_p.copy()
print(data_p_backup.shape, d.DT)
par_mutter = {'k': 7, 'b': -100, 'r': 30}
new_data_p = []
for idat in range(data_p.shape[0]):
    new_data_p.append(np.expand_dims(ld.mutter(data_p[idat, ...], **par_mutter), 0))
new_data_p = np.concatenate(new_data_p)
print('data_p.shape',data_p.shape)
print('new_data_p.shape',new_data_p.shape)
# Out:
# (95, 324, 3000)
# (95, 324, 3000) None
# data_p.shape (95, 324, 3000)
# new_data_p.shape (95, 324, 3000)

# %% [markdown]
# ## Analyze data and muttered data

# %%
print(data_p.shape)
nshots=data_p.shape[0]
for idx in range(2):
    shot=data_p[idx,::]
    shot_processed=new_data_p[idx,::]
    vis.plot_shot(np.concatenate([np.flip(shot, 0), shot_processed],axis=0),pclip=0.0525,title=str(src.x[idx]),dpi=300)
# Out:
# (95, 324, 3000)

# %% [markdown]
# ## Make a new folder with zero shot files to fill with field data afterwards

# %%
print(os.getcwd())
from glob import glob
print(d._root_su)
print(root_su_field)
print(os.listdir(d._root_su))
api._cmd('rm '+os.path.join(d._root_su,'*'))
api._cmd('rm '+os.path.join(root_su_field,'*'))
nshots=data_p.shape[0]
for ii in range(nshots):
    api._cmd('scp seis_p.su.shot1 '+os.path.join(d._root_su,'seis_p.su.shot'+str(ii+1)))
# Out:
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha
# ./out_for_pasha/su
# ./out_for_pasha/su/field/
# ['seis_p.su.shot34', 'seis_p.su.shot39', 'seis_p.su.shot76', 'seis_p.su.shot50', 'seis_p.su.shot88', 'seis_p.su.shot13', 'seis_p.su.shot1', 'seis_p.su.shot84', 'seis_p.su.shot81', 'seis_p.su.shot29', 'seis_p.su.shot19', 'seis_p.su.shot25', 'seis_p.su.shot63', 'seis_p.su.shot80', 'seis_p.su.shot40', 'seis_p.su.shot53', 'seis_p.su.shot6', 'seis_p.su.shot36', 'seis_p.su.shot54', 'seis_p.su.shot87', 'seis_p.su.shot44', 'seis_p.su.shot85', 'seis_p.su.shot61', 'seis_p.su.shot52', 'seis_p.su.shot23', 'seis_p.su.shot57', 'seis_p.su.shot46', 'seis_p.su.shot65', 'seis_p.su.shot74', 'seis_p.su.shot4', 'seis_p.su.shot48', 'seis_p.su.shot24', 'field', 'seis_p.su.shot56', 'seis_p.su.shot8', 'seis_p.su.shot35', 'seis_p.su.shot64', 'seis_p.su.shot62', 'seis_p.su.shot37', 'seis_p.su.shot7', 'seis_p.su.shot69', 'seis_p.su.shot27', 'seis_p.su.shot2', 'seis_p.su.shot90', 'seis_p.su.shot67', 'seis_p.su.shot31', 'seis_p.su.shot73', 'seis_p.su.shot83', 'seis_p.su.shot3', 'seis_p.su.shot42', 'seis_p.su.shot32', 'seis_p.su.shot60', 'seis_p.su.shot71', 'seis_p.su.shot12', 'seis_p.su.shot9', 'seis_p.su.shot51', 'seis_p.su.shot11', 'seis_p.su.shot38', 'seis_p.su.shot33', 'seis_p.su.shot89', 'seis_p.su.shot77', 'seis_p.su.shot47', 'seis_p.su.shot21', 'seis_p.su.shot72', 'seis_p.su.shot18', 'seis_p.su.shot55', 'seis_p.su.shot94', 'seis_p.su.shot92', 'seis_p.su.shot68', 'seis_p.su.shot70', 'seis_p.su.shot45', 'seis_p.su.shot5', 'seis_p.su.shot28', 'seis_p.su.shot10', 'seis_p.su.shot16', 'seis_p.su.shot91', 'seis_p.su.shot20', 'seis_p.su.shot41', 'seis_p.su.shot30', 'seis_p.su.shot95', 'seis_p.su.shot58', 'seis_p.su.shot79', 'seis_p.su.shot75', 'seis_p.su.shot26', 'seis_p.su.shot93', 'seis_p.su.shot59', 'seis_p.su.shot14', 'seis_p.su.shot15', 'seis_p.su.shot66', 'seis_p.su.shot78', 'seis_p.su.shot82', 'seis_p.su.shot17', 'seis_p.su.shot49', 'seis_p.su.shot22', 'seis_p.su.shot86', 'seis_p.su.shot43']
# rm ./out_for_pasha/su/*
# rm ./out_for_pasha/su/field/*
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot1
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot2
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot3
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot4
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot5
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot6
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot7
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot8
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot9
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot10
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot11
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot12
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot13
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot14
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot15
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot16
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot17
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot18
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot19
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot20
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot21
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot22
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot23
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot24
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot25
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot26
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot27
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot28
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot29
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot30
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot31
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot32
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot33
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot34
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot35
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot36
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot37
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot38
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot39
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot40
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot41
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot42
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot43
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot44
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot45
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot46
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot47
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot48
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot49
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot50
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot51
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot52
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot53
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot54
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot55
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot56
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot57
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot58
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot59
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot60
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot61
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot62
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot63
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot64
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot65
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot66
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot67
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot68
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot69
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot70
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot71
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot72
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot73
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot74
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot75
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot76
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot77
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot78
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot79
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot80
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot81
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot82
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot83
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot84
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot85
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot86
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot87
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot88
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot89
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot90
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot91
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot92
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot93
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot94
# scp seis_p.su.shot1 ./out_for_pasha/su/seis_p.su.shot95

# %% [markdown]
# ## Save field data to a new folder in /su/

# %%
def copy_su_from_to(path_from, path_to):
    """ Copy files matching *.su.* from one folder to another folder"""
    os.makedirs(path_to, exist_ok=True)
    su_files = glob(path_from + '/*.su.*')
    su_files = [f for f in su_files if '.it' not in f]
    print(f'Found {len(su_files)} *.su.* files in {path_from}')

    commands = []
    print(f'Copy files from {path_from} to {path_to}')
    for f in su_files:
        commands.append(f'cp {f} {path_to}')
    with multiprocessing.Pool() as pool:
        pool.map(os.system, commands)

# %%
print(root_su_field)
copy_su_from_to(d._root_su,root_su_field)
# Out:
# ./out_for_pasha/su/field/
# Found 95 *.su.* files in ./out_for_pasha/su
# Copy files from ./out_for_pasha/su to ./out_for_pasha/su/field/

# %% [markdown]
# # Write field data into created .su files

# %%
def get_fnames_pattern(pattern):    
    fnames = natsorted(glob(pattern))
    fnames = [f for f in fnames if '.it' not in f]
    print(f'{len(fnames)} files found in {pattern}')
    return fnames
fnames = get_fnames_pattern(root_su_field + '*.su.*')
print(fnames)
for i, f in enumerate(fnames):
    with segyio.su.open(f, "r+", endian='little', ignore_geometry=True) as dst:
        tmp = new_data_p[i, :, ::d.NDT]
        dst.trace = tmp
        print(f, dst.tracecount, tmp.shape, end='\r')
# Out:
# 95 files found in ./out_for_pasha/su/field/*.su.*
# ['./out_for_pasha/su/field/seis_p.su.shot1', './out_for_pasha/su/field/seis_p.su.shot2', './out_for_pasha/su/field/seis_p.su.shot3', './out_for_pasha/su/field/seis_p.su.shot4', './out_for_pasha/su/field/seis_p.su.shot5', './out_for_pasha/su/field/seis_p.su.shot6', './out_for_pasha/su/field/seis_p.su.shot7', './out_for_pasha/su/field/seis_p.su.shot8', './out_for_pasha/su/field/seis_p.su.shot9', './out_for_pasha/su/field/seis_p.su.shot10', './out_for_pasha/su/field/seis_p.su.shot11', './out_for_pasha/su/field/seis_p.su.shot12', './out_for_pasha/su/field/seis_p.su.shot13', './out_for_pasha/su/field/seis_p.su.shot14', './out_for_pasha/su/field/seis_p.su.shot15', './out_for_pasha/su/field/seis_p.su.shot16', './out_for_pasha/su/field/seis_p.su.shot17', './out_for_pasha/su/field/seis_p.su.shot18', './out_for_pasha/su/field/seis_p.su.shot19', './out_for_pasha/su/field/seis_p.su.shot20', './out_for_pasha/su/field/seis_p.su.shot21', './out_for_pasha/su/field/seis_p.su.shot22', './out_for_pasha/su/field/seis_p.su.shot23', './out_for_pasha/su/field/seis_p.su.shot24', './out_for_pasha/su/field/seis_p.su.shot25', './out_for_pasha/su/field/seis_p.su.shot26', './out_for_pasha/su/field/seis_p.su.shot27', './out_for_pasha/su/field/seis_p.su.shot28', './out_for_pasha/su/field/seis_p.su.shot29', './out_for_pasha/su/field/seis_p.su.shot30', './out_for_pasha/su/field/seis_p.su.shot31', './out_for_pasha/su/field/seis_p.su.shot32', './out_for_pasha/su/field/seis_p.su.shot33', './out_for_pasha/su/field/seis_p.su.shot34', './out_for_pasha/su/field/seis_p.su.shot35', './out_for_pasha/su/field/seis_p.su.shot36', './out_for_pasha/su/field/seis_p.su.shot37', './out_for_pasha/su/field/seis_p.su.shot38', './out_for_pasha/su/field/seis_p.su.shot39', './out_for_pasha/su/field/seis_p.su.shot40', './out_for_pasha/su/field/seis_p.su.shot41', './out_for_pasha/su/field/seis_p.su.shot42', './out_for_pasha/su/field/seis_p.su.shot43', './out_for_pasha/su/field/seis_p.su.shot44', './out_for_pasha/su/field/seis_p.su.shot45', './out_for_pasha/su/field/seis_p.su.shot46', './out_for_pasha/su/field/seis_p.su.shot47', './out_for_pasha/su/field/seis_p.su.shot48', './out_for_pasha/su/field/seis_p.su.shot49', './out_for_pasha/su/field/seis_p.su.shot50', './out_for_pasha/su/field/seis_p.su.shot51', './out_for_pasha/su/field/seis_p.su.shot52', './out_for_pasha/su/field/seis_p.su.shot53', './out_for_pasha/su/field/seis_p.su.shot54', './out_for_pasha/su/field/seis_p.su.shot55', './out_for_pasha/su/field/seis_p.su.shot56', './out_for_pasha/su/field/seis_p.su.shot57', './out_for_pasha/su/field/seis_p.su.shot58', './out_for_pasha/su/field/seis_p.su.shot59', './out_for_pasha/su/field/seis_p.su.shot60', './out_for_pasha/su/field/seis_p.su.shot61', './out_for_pasha/su/field/seis_p.su.shot62', './out_for_pasha/su/field/seis_p.su.shot63', './out_for_pasha/su/field/seis_p.su.shot64', './out_for_pasha/su/field/seis_p.su.shot65', './out_for_pasha/su/field/seis_p.su.shot66', './out_for_pasha/su/field/seis_p.su.shot67', './out_for_pasha/su/field/seis_p.su.shot68', './out_for_pasha/su/field/seis_p.su.shot69', './out_for_pasha/su/field/seis_p.su.shot70', './out_for_pasha/su/field/seis_p.su.shot71', './out_for_pasha/su/field/seis_p.su.shot72', './out_for_pasha/su/field/seis_p.su.shot73', './out_for_pasha/su/field/seis_p.su.shot74', './out_for_pasha/su/field/seis_p.su.shot75', './out_for_pasha/su/field/seis_p.su.shot76', './out_for_pasha/su/field/seis_p.su.shot77', './out_for_pasha/su/field/seis_p.su.shot78', './out_for_pasha/su/field/seis_p.su.shot79', './out_for_pasha/su/field/seis_p.su.shot80', './out_for_pasha/su/field/seis_p.su.shot81', './out_for_pasha/su/field/seis_p.su.shot82', './out_for_pasha/su/field/seis_p.su.shot83', './out_for_pasha/su/field/seis_p.su.shot84', './out_for_pasha/su/field/seis_p.su.shot85', './out_for_pasha/su/field/seis_p.su.shot86', './out_for_pasha/su/field/seis_p.su.shot87', './out_for_pasha/su/field/seis_p.su.shot88', './out_for_pasha/su/field/seis_p.su.shot89', './ ...
# ./out_for_pasha/su/field/seis_p.su.shot2 324 (324, 3000)
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/env/lib/python3.6/site-packages/segyio/utils.py:23: RuntimeWarning: Implicit conversion from float64 to float32 (narrowing)
#   warnings.warn(msg.format(x.dtype, dtype), RuntimeWarning)
# ./out_for_pasha/su/field/seis_p.su.shot95 324 (324, 3000)

# %%
def zero_below_freq(dat, fhi, dt, disable=False, reverse=False):
    """ Input zeros into frequency spectrum of data below or above specified frequency.
        by Oleg Ovcharenko, KAUST, 2021
       
    Args:
        dat(np.ndarray): 2D array [noffsets, ntimes]
        fhi(float): threshold frequency, Hz
        dt(float): temporal sampling, sec
        disable(bool): do nothing, return input data
        reverse(bool): when True, set zeros above fhi, otherwise below
    """
#     print('Function from cell!!!!!!!!!!!!!!!!!!!!!!!!')
    if disable:
        return dat
    h, w = dat.shape[-2:]
    dat_fx = np.fft.rfft(dat, w)
    ff = np.fft.rfftfreq(dat.shape[-1], d=dt)
    if not reverse:
        where_to_zero = np.where(ff < fhi)[0]
    else:
        where_to_zero = np.where(ff >= fhi)[0]
    dat_fx[..., where_to_zero] = 0. + 0. * 1j
    out = np.fft.irfft(dat_fx, w)
    return out
def filter_seismic_data(path,dt=0.002,corner_frequency=8,fmax=10):
    # d=api.Denise('./',verbose=1)
#     d=api.Denise('/home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master',verbose=1)
    denise_root = '../'
#     d = api.Denise(denise_root,verbose=1)
    print(d.get_shots_from_directory)
    print(path)
    shots,filenames=d.get_shots_from_directory(path,return_filenames=True)
#     shots=shots[0:2]
#     filenames=filenames[0:2]
    print('low frequency data corner frequency, ',corner_frequency)
    print(f'Read {len(shots)} shots {shots[0].shape} into list')
    counter=0
    delete_low_freqs=True
    for shot,filename in zip(shots,filenames):
        ################    processing stage for plotting
        filtered_shot=bandpass(shot,fhi=6, dt=dt,order=8, btype='low')
        ################    processing stage 1
        filtered_shot2=bandpass(shot,flo=corner_frequency,dt=dt,order=8,btype='high')
        filtered_shot2_=bandpass(shot,flo=corner_frequency,fhi=6,dt=dt,order=8,btype='band') #for plotting purposes
        ################    processing stage 2
        filtered_shot3=zero_below_freq(filtered_shot2,corner_frequency,dt, disable=False,reverse=False)
        filtered_shot3_=zero_below_freq(filtered_shot2_,corner_frequency,dt, disable=False,reverse=False)
        ################    processing stage 3
        filtered_shot4=ld.mutter(filtered_shot3,**par_mutter)
#         new_data_p.append(np.expand_dims(ld.mutter(data_p[idat, ...], **par_mutter), 0))
        ################
        plotting_flag=0
        if plotting_flag==1:
            shots_list=[0,22,44,66]
            if counter in shots_list:
                plot_shot(shot,pclip=0.05,folder_path='./pictures_for_check',file_path='shot_'+str(counter)+'.png',show=0)
                plot_shot(filtered_shot2,pclip=0.05,folder_path='./pictures_for_check',file_path='filtered_shot2_'+str(counter)+'.png',show=0)
                plot_shot(filtered_shot3,pclip=0.05,folder_path='./pictures_for_check',file_path='filtered_shot3_'+str(counter)+'.png',show=0)
                plot_shot(filtered_shot4,pclip=0.05,folder_path='./pictures_for_check',file_path='filtered_shot4_'+str(counter)+'.png',show=0)
                vis.plot_shot(shot,pclip=0.0525,title='shot_'+str(counter),dpi=300)
                vis.plot_shot(filtered_shot2,pclip=0.0525,title='filtered_shot2_'+str(counter),dpi=300)
                vis.plot_shot(filtered_shot3,pclip=0.0525,title='filtered_shot3_'+str(counter),dpi=300)
                vis.plot_shot(filtered_shot4,pclip=0.0525,title='filtered_shot4_'+str(counter),dpi=300)
                freqs,ps=plot_spectrum(shot,dt,fmax=fmax,folder_path='./pictures_for_check',
                                       file_path='spectrum_original_shot_'+str(counter)+'.png')
                freqs,ps=plot_spectrum(filtered_shot2,dt,fmax=fmax,folder_path='./pictures_for_check',
                                       file_path='spectrum_filtered_shot_'+str(counter)+'.png')
                freqs,ps=plot_spectrum(filtered_shot3,dt,fmax=fmax,folder_path='./pictures_for_check',
                                       file_path='spectrum_del_freqs_shot_'+str(counter)+'.png')
                freqs,ps=plot_spectrum(filtered_shot4,dt,fmax=fmax,folder_path='./pictures_for_check',
                       file_path='spectrum_del_freqs2_shot_'+str(counter)+'.png')
        ################    chosen processing    
        with segyio.su.open(filename,"r+",endian='little',ignore_geometry=True) as dst:
            if delete_low_freqs==False: 
                print('we only filter')
                dst.trace=filtered_shot2    #only high-pass filtered data
            else:   
                print('we deleted low frequencies')
                dst.trace=filtered_shot3    #high-pass filtered data, frequencies belof Fc are zeroed out
            dst.trace=filtered_shot4
        # shot_read,read_filename=d.get_shots_from_datadir(keys=[filename],return_filenames=True); shot_read=shot_read[0]
        counter=counter+1
    return None


print(os.getcwd())
print(d.DT)
print(d.get_shots_from_directory)
su_field_path1 = os.path.join(os.getcwd(),'su_field_high_pass_5_hz/')
su_field_path2 = os.path.join(os.getcwd(),'su_field/')


api._cmd('rm '+os.path.join(su_field_path1,'*'))
copy_su_from_to(root_su_field,su_field_path1)
filter_seismic_data(su_field_path1,dt=0.002,corner_frequency=5,fmax=5.2)

api._cmd('rm '+os.path.join(su_field_path2,'*'))
copy_su_from_to(root_su_field,su_field_path2)
# Out:
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha
# None
# <bound method Denise.get_shots_from_directory of DENISE-Black-Edition:
# 	../
# Save folder:
# 	./out_for_pasha/
# Run .help() for more details>
# rm /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/su_field_high_pass_5_hz/*
# Found 95 *.su.* files in ./out_for_pasha/su/field/
# Copy files from ./out_for_pasha/su/field/ to /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/su_field_high_pass_5_hz/
# <bound method Denise.get_shots_from_directory of DENISE-Black-Edition:
# 	../
# Save folder:
# 	./out_for_pasha/
# Run .help() for more details>
# /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/su_field_high_pass_5_hz/
# low frequency data corner frequency,  5
# Read 95 shots (324, 3000) into list
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# we deleted low frequencies
# rm /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/su_field/*
# Found 95 *.su.* files in ./out_for_pasha/su/field/
# Copy files from ./out_for_pasha/su/field/ to /home/plotnips/Dropbox/Log_extrapolation/scripts/DENISE-Black-Edition-master/for_pasha/su_field/

# %%
print(d.DT)
counter=0
shots_rec,filenames=d.get_shots_from_directory(su_field_path1,keys=['_p'],return_filenames=True)
shots_rec=shots_rec[0:2]
filenames=filenames[0:2]
for shot_11 in shots_rec:
    vis.plot_shot(shot_11,pclip=0.0525,title='recorded_shot_p1_'+str(counter),dpi=300)
    freqs,ps=plot_spectrum(shot_11,0.002,fmax=5.2,folder_path='./pictures_for_check',
                                       file_path='recorded_shot_spectrum_'+str(counter)+'.png')
    counter=counter+1
# Out:
# None
# pic saved to  ./pictures_for_check/recorded_shot_spectrum_0.png
# pic saved to  ./pictures_for_check/recorded_shot_spectrum_1.png

# %%
d.save_folder = os.path.join(root_fwi,'fwi_full_spectrum','fld')
mpl.rcParams['figure.dpi']= 300
d.verbose = 2

models, fnames = d.get_fwi_models(['vp', 'stage'], return_filenames=True)
for m, f in zip(models, fnames):
    vis.plot_log_model(m, dx, nx0, nz0, src, log=wlog, log_location=log_location, **limits_vp)

# %% [markdown]
# ### Well-logs
# Plot logs in true model (dashed) and inverted models (solid) for every inversion stage

# %%
# Load inverted models from all stages
vvr = {'vp': None, 'vs': None, 'rho': None}
for k in vvr.keys():
    vvr[k], fnames = d.get_fwi_models([k + '_stage'], return_filenames=True)

for i in range(len(vvr['vp'])):
    plot_logs(model_log, api.Model(vvr['vp'][i], vvr['vs'][i], vvr['rho'][i], dx), log_idx)

# %% [markdown]
# ### Gradients

# %%
d.verbose = 0
grads, fnames = d.get_fwi_gradients(return_filenames=True)
for g, f in zip(grads, fnames):
    plot_model(g, f)

# %%
def get_model_last():
    all_fnames = []
    # vps, fnames = d.get_fwi_models(['vp', 'stage'], return_filenames=True)
    vps, fnames = d.get_fwi_models(['vp'], return_filenames=True)
    all_fnames += fnames
    vss, fnames = d.get_fwi_models(['vs'], return_filenames=True)
    all_fnames += fnames
    rhos, fnames = d.get_fwi_models(['rho'], return_filenames=True)
    all_fnames += fnames
    print(all_fnames)
    if all_fnames:
        for f in all_fnames:
            if not f.split('/')[-1] in os.listdir(f'{root_fwi}start/'):
                command = f'cp {f} {root_fwi}start/'
                print(command)
                os.system(command)
    if vps:
        print(f'Init new starting model from {fnames[-1]}')
        model_last = api.Model(vps[-1], vss[-1], rhos[-1], dx)
    # print(vps)
    return model_last
    # return None
model_last=get_model_last()

# %% [markdown]
# # Compare wavefiedls before/after

# %%
vps, fnames = d.get_fwi_models(['vp_stage'], return_filenames=True)
vss, fnames = d.get_fwi_models(['vs_stage'], return_filenames=True)
rhos, fnames = d.get_fwi_models(['rho_stage'], return_filenames=True)
print(d.save_folder)
if vps:
    model_last = api.Model(vps[-1], vss[-1], rhos[-1], dx)
    print(f'Found last model at {fnames[-1]}')
else:
    print(f'Not found the inverted model in {d.save_folder}!')

# %%
d.save_folder = root_fwi[:-1] + '_wavefield/'
print(f'{root_fwi[:-1]} --> {d.save_folder}')

# %%
par_forward = {'run_command': 'mpirun -np 30', 'disable': False}
print(par_forward)

# %%
d.NPROCX = 1
d.NPROCY = 1
d.verbose=1
d.forward(model_last, src, rec, **par_forward)

# %%
def divmax(x): return x / np.max(np.abs(x))
d.verbose = 0    # don't show redundant print outs
if d.DT is None:
    d.DT = 0.002
shots = d.get_shots(keys=['_p'])
# shots = [ld.bandpass(s, fs=1./(d.DT * d.NDT), **par_bp) for s in d.get_shots(keys=['_p'])]
print(f'Read {len(shots)} shots {shots[0].shape} into list')

mpl.rcParams['figure.dpi']= 300
# for ishot in [int(np.floor(x)) for x in np.linspace(0, len(shots)-1, 5)]:
for ishot in [19, 62]:
    print(ishot)
    shot_s = divmax(shots[ishot])
    shot_f = divmax(data_p[ishot, :, ::d.NDT])
#     vis.plot_shot(np.concatenate([np.flip(shot_s, 0), shot_f], axis=0), pclip=0.05)
    vis.plot_compare_stripes(shot_s, shot_f, pclip=0.0125, colorbar=False, dt=d.DT, dx=dx)
