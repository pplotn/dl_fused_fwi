# %% [markdown]
# # FWI on field data (CGG Broadseis)
#
# by Oleg Ovcharenko
#
# oleg.ovcharenko@kaust.edu.sa
#
# KAUST, 2021

# %%
import os
import sys
import copy
import glob
import numpy as np
import importlib
import multiprocessing

import segyio
from scipy import signal, ndimage
from natsort import natsorted
from skimage.transform import rescale, resize

import shared as sd
import loaders as ld
import vis

from IPython.display import clear_output

# MAKE SURE THIS POINTS TO WHRE DENISE IS
sys.path.append(os.path.abspath('../'))
import pyapi_denise as api
print(f'Python: {sys.prefix}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8b8a94a41776> in <module>
#       7 import multiprocessing
#       8
# ----> 9 import segyio
#      10 from scipy import signal, ndimage
#      11 from natsort import natsorted
#
# ModuleNotFoundError: No module named 'segyio'

# %%
# # This is to prevent error "this loop already runnign when doing magical %run <<notebook name>>"
import nest_asyncio
nest_asyncio.apply()

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# mpl.rcParams['figure.dpi']= 100
fontsize = 10
params = {
    # 'text.latex.preamble': ['\\usepackage{gensymb}'],
    # 'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'figure.dpi' : 100,
    # 'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize':fontsize,  # fontsize for x and y labels (was 10)
    'axes.titlesize':fontsize,
    'font.size':fontsize,  # was 10
    'legend.fontsize': fontsize,  # was 10
    'xtick.labelsize':fontsize,
    'ytick.labelsize':fontsize,
    # 'text.usetex': True,
    # 'figure.figsize': [3.39, 2.10],
    'font.family': 'serif',
}
mpl.rcParams.update(params)

# %%
root_fwi = './out_for_pasha/'

# %% [markdown]
# # Init Denise API

# %%
denise_root = '../den/'
d = api.Denise(denise_root, verbose=1)
# Out:
# Init Python 3 API for Denise-Black-Edition.
# Check binary in ../den/bin/denise
# Parse ../den/par/DENISE_marm_OBC.inp
# Current directory is /home/ovcharoo/work/for_pasha
# Init paths at ./outputs/

# %%
# d.parser_report()

# %% [markdown]
# ## Work directory
# Where to output everything

# %%
d.save_folder = root_fwi
d.set_paths()
# Out:
# Current directory is /home/ovcharoo/work/for_pasha
# Init paths at ./out_for_pasha/

# %% [markdown]
# # Get acquitision details

# %%
shot_id_min = 60
n_selected_shots = 80
njump_src = 8
shot_id_max = shot_id_min + (n_selected_shots-1) * njump_src

# %%
# %run ./fwi_shared_check.ipynb
# Out:
# 80/80
# Before prep:	(80, 648, 3526)
# Data cube:	(80, 324, 3000)
# Extended cube:	(80, 324, 3100)
# [80, 324, 3050] (80, 324, 3000)
# [80, 324, 3150] (80, 324, 3100)
# Assume even averacge spacing between sources
#  150.0 m ~ 6 grid nodes
# First source:	1125.0 m
# Last source:	12950.0 m
# name:
# x	(80,):	min: 1125.0	max: 12975.0
# y	(80,):	min: 50.0	max: 50.0
# wavelets:	None
# z	(80,):	min: 0.0	max: 0.0
# nshot:	80
# td	(80,):	min: 0.0	max: 0.0
# fc	(80,):	min: 8.0	max: 8.0
# amp	(80,):	min: 1.0	max: 1.0
# angle	(80,):	min: 0.0	max: 0.0
# QUELLTYPB:	1
# src_type	(80,):	min: 1.0	max: 1.0
# drec:	25.0 m
# x	(324,):	min: 1275.0	max: 9350.0
# y	(324,):	min: 100.0	max: 100.0
# many:	[x	(324,):	min: 1275.0	max: 9350.0
# y	(324,):	min: 100.0	max: 100.0
# name:	]

# %%
print('Field data spacing between sources {:.2f} m'.format(np.mean(src_.x[1:] - src_.x[:-1])))
# Out:
# Field data spacing between sources 149.75 m

# %%
vp_baseline = vp.copy()
print(vp.shape)

marm_path = os.path.join(root_fwi, 'start/')
os.makedirs(marm_path, exist_ok=True)
print(marm_path)
if not 'marmousi_II_marine.vp' in os.listdir(marm_path):
    # Download Marmousi II model
    os.system(f'wget https://github.com/daniel-koehn/DENISE-Benchmark/raw/master/Marmousi-II/start/marmousi_II_marine.vp -P {marm_path}')
    os.system(f'wget https://github.com/daniel-koehn/DENISE-Benchmark/raw/master/Marmousi-II/start/marmousi_II_marine.vs -P {marm_path}')
    os.system(f'wget https://github.com/daniel-koehn/DENISE-Benchmark/raw/master/Marmousi-II/start/marmousi_II_marine.rho -P {marm_path}')

    # Download initial model for FWI
    os.system(f'wget https://github.com/daniel-koehn/DENISE-Benchmark/raw/master/Marmousi-II/start/marmousi_II_start_1D.vp -P {marm_path}')
    os.system(f'wget https://github.com/daniel-koehn/DENISE-Benchmark/raw/master/Marmousi-II/start/marmousi_II_start_1D.vs -P {marm_path}')
    os.system(f'wget https://github.com/daniel-koehn/DENISE-Benchmark/raw/master/Marmousi-II/start/marmousi_II_start_1D.rho -P {marm_path}')
    
def get_vp_vs_rho(vp):
    vp = extend(vp, 15, 0)

    print(f'Reshape {vp.shape} into {wb_taper.shape}...')

    vp = resize(vp, wb_taper.shape, anti_aliasing=True)
    vp = np.where(vp <= 1500.0, 1490.0, vp)
    vp = extend(vp, 0, 264 + 10 * 8)

    # shear velocity, [m/s]
    vs = vp.copy() / (3 ** 0.5)
    vs = np.where(vp < 1.01 * np.min(vp), 0, vs)

    # density, [kg/m3] 
    rho = 1e3*0.3 * vp.copy()**0.25
    rho = np.where(vp < 1.01 * np.min(vp), 1000, rho)
    return vp, vs, rho
# Out:
# (152, 600)
# ./out_for_pasha/start/

# %% [markdown]
# Extend the model so it accommodates full streamer length for the last shot

# %%
vp = extend(model.vp, 0, 264 + 10 * 8)
vp_long = vp.copy()
print(vp_long.shape)
# Out:
# (152, 944)

# %% [markdown]
# ## Acquisition design

# %%
# Wavelet scaler to match field and synthetic
wavefield_amp_ratio = 77.08343437940496

# %%
# Set custom wavelet
wls = bpw[:, ::2]
src.wavelets = wavefield_amp_ratio * wls[:, :limit_nt]

vis.plot_acquisition(vp, dx, src, rec, title='Vp')
print(model)
# Out:
# vp:	(152, 600), 1490.0000, 2969.2560 m/s
#
# vs:	(152, 600), 0.0000, 1714.3007 m/s
#
# rho:	(152, 600), 1000.0000, 2214.5349 m/s
#
# dx:	25.0000
# Size:
# 	OX:	min 0.0000	max 14975.0000 m
# Size:
# 	OZ:	min 0.0000	max 3775.0000 m

# %%
wb_taper = np.where(vp < 1.01 * vp.min(), 1, 0)

# %%
# log = model.vp[:, log_idx]
log = model.vp[-len(wlog):, log_idx]
# model_log = copy.deepcopy(model)

log_dict = {'data':wlog, 'loc': log_loc}
vis.plot_acquisition(vp[:, :500], dx, src, rec, log=log_dict)
vis.savefig('vinit.png')
# Out:
# Save /home/ovcharoo/Dropbox/WORK_HARD/low_elastic/tex/GEOPHYSICS_21/pic/vinit.png

# %%
print(wb_taper.shape)
# Out:
# (152, 944)

# %% [markdown]
# Create new initial (orange line). This is to see whether knowledge about exact waterbottom will improve results

# %%
new_vp = np.zeros_like(model.vp)
vps=[]
for i in range(wb_taper.shape[-1]):
    wb = wb_taper.shape[0] - np.argmax(wb_taper[:,i]) + 2
    fun = vmin * np.ones_like(new_vp[:, 0:1])
    fun[wb:, :] = 690 + fun[wb:, :] + 6 * np.expand_dims(np.arange(len(fun[wb:, 0])), 1)
    fun = fun[::-1, :]
    vps.append(fun)
new_vp = np.concatenate(vps, -1)
new_vp = gaussian_filter(new_vp.copy(), **sigma_truncate)

print(new_vp.shape)
print(f'Well-log from {log_loc} maps into ix: {log_idx}')
plt.figure(); plt.plot(wlog, 'k--'); plt.plot(log[-len(wlog):]); plt.plot(new_vp[-len(wlog):, log_idx])
# Out:
# (152, 944)
# Well-log from 10500 maps into ix: 420

# %% [markdown]
# Set new model as initial

# %%
vp = new_vp.copy()
vs = vp.copy() / (3 ** 0.5)
rho = 1e3*0.3 * vp.copy()**0.25

vp = np.where(wb_taper, np.min(vp_cgg), vp)
vs = np.where(wb_taper, 0, vs)
rho = np.where(wb_taper, 1000, rho)

# log = vplog.copy()
model = api.Model(vp, vs, rho, dx)

# %%
print(src, end='\n\n------------\n')
print(rec)
# Out:
# name:
# x	(80,):	min: 1125.0	max: 12975.0
# y	(80,):	min: 50.0	max: 50.0
# wavelets	(80, 3000):	min: -400.8610078720592	max: 484.6122728113698
# z	(80,):	min: 0.0	max: 0.0
# nshot:	80
# td	(80,):	min: 0.0	max: 0.0
# fc	(80,):	min: 8.0	max: 8.0
# amp	(80,):	min: 1.0	max: 1.0
# angle	(80,):	min: 0.0	max: 0.0
# QUELLTYPB:	1
# src_type	(80,):	min: 1.0	max: 1.0
#
# ------------
# x	(324,):	min: 1275.0	max: 9350.0
# y	(324,):	min: 100.0	max: 100.0
# many:	[x	(324,):	min: 1275.0	max: 9350.0
# y	(324,):	min: 100.0	max: 100.0
# name:	]

# %% [markdown]
# ## Generate true waveforms

# %% [markdown]
# Set some runtime parameters which are different from defaults. Check defaults by runnning `help()`

# %%
# Elastic modeling
d.verbose = 1
d.PHYSICS = 1
d.SEISMO = 2
d.DT = dDT
d.NT = data_p.shape[-1]
d.TIME = dDT * d.NT
#
d.FC_SPIKE_2 = 10
d.REC_INCR_X = dsrc
d.N_STREAMER = len(rec)

# d.TESTSHOT_START = np.round(0.1 * len(src))
# d.TESTSHOT_END = np.round(0.9 * len(src))
# d.TESTSHOT_INCR = 5

d.TESTSHOT_START = 1
d.TESTSHOT_END = len(src)
d.TESTSHOT_INCR = 10

d.QUELLTYPB = 4
d.QUELLART = 3  

d.WRITE_STF = 0

# Acoustic case 
# d.PHYSICS = 2
# src.wavelets = -wls[:, :limit_nt]

print(d.DT, d.NT)
# Out:
# 0.002 3000

# %% [markdown]
# ### Run forward modeling

# %%
d.NPROCX = 1
d.NPROCY = 1
par_forward = {'run_command': 'mpirun -np 40', 'disable': False}

# %%
d.forward(model, src, rec, **par_forward)
# Out:
# Current directory is /home/ovcharoo/work/for_pasha
# Init paths at ./out_for_pasha/
# Init model:
# 	152 x 944, dx = 25.0 m
# Check max source frequency:
# 	min Vs: 931.1580816910116 m/s
# 	min Vp: 1490.0 m/s
# 	Number of gridpoints per minimum wavelength = 3.69
# 	Maximum source wavelet frequency = 10.093854544076006 Hz
# Check domain decomposition for parallelization:
# 	in X-direction, NX % NPROCX, 944 % 1 = 0
# 	in Y-direction, NY % NPROCY, 152 % 1 = 0
# Write ./out_for_pasha/start/model.vp
# Write ./out_for_pasha/start/model.vs
# Write ./out_for_pasha/start/model.rho
# Enable streamer mode!
# 	source 1: ./out_for_pasha/receiver/receivers_shot_1
# 	source 2: ./out_for_pasha/receiver/receivers_shot_2
# 	source 3: ./out_for_pasha/receiver/receivers_shot_3
# 	source 4: ./out_for_pasha/receiver/receivers_shot_4
# 	source 5: ./out_for_pasha/receiver/receivers_shot_5
# 	source 6: ./out_for_pasha/receiver/receivers_shot_6
# 	source 7: ./out_for_pasha/receiver/receivers_shot_7
# 	source 8: ./out_for_pasha/receiver/receivers_shot_8
# 	source 9: ./out_for_pasha/receiver/receivers_shot_9
# 	source 10: ./out_for_pasha/receiver/receivers_shot_10
# 	source 11: ./out_for_pasha/receiver/receivers_shot_11
# 	source 12: ./out_for_pasha/receiver/receivers_shot_12
# 	source 13: ./out_for_pasha/receiver/receivers_shot_13
# 	source 14: ./out_for_pasha/receiver/receivers_shot_14
# 	source 15: ./out_for_pasha/receiver/receivers_shot_15
# 	source 16: ./out_for_pasha/receiver/receivers_shot_16
# 	source 17: ./out_for_pasha/receiver/receivers_shot_17
# 	source 18: ./out_for_pasha/receiver/receivers_shot_18
# 	source 19: ./out_for_pasha/receiver/receivers_shot_19
# 	source 20: ./out_for_pasha/receiver/receivers_shot_20
# 	source 21: ./out_for_pasha/receiver/receivers_shot_21
# 	source 22: ./out_for_pasha/receiver/receivers_shot_22
# 	source 23: ./out_for_pasha/receiver/receivers_shot_23
# 	source 24: ./out_for_pasha/receiver/receivers_shot_24
# 	source 25: ./out_for_pasha/receiver/receivers_shot_25
# 	source 26: ./out_for_pasha/receiver/receivers_shot_26
# 	source 27: ./out_for_pasha/receiver/receivers_shot_27
# 	source 28: ./out_for_pasha/receiver/receivers_shot_28
# 	source 29: ./out_for_pasha/receiver/receivers_shot_29
# 	source 30: ./out_for_pasha/receiver/receivers_shot_30
# 	source 31: ./out_for_pasha/receiver/receivers_shot_31
# 	source 32: ./out_for_pasha/receiver/receivers_shot_32
# 	source 33: ./out_for_pasha/receiver/receivers_shot_33
# 	source 34: ./out_for_pasha/receiver/receivers_shot_34
# 	source 35: ./out_for_pasha/receiver/receivers_shot_35
# 	source 36: ./out_for_pasha/receiver/receivers_shot_36
# 	source 37: ./out_for_pasha/receiver/receivers_shot_37
# 	source 38: ./out_for_pasha/receiver/receivers_shot_38
# 	source 39: ./out_for_pasha/receiver/receivers_shot_39
# 	source 40: ./out_for_pasha/receiver/receivers_shot_40
# 	source 41: ./out_for_pasha/receiver/receivers_shot_41
# 	source 42: ./out_for_pasha/receiver/receivers_shot_42
# 	source 43: ./out_for_pasha/receiver/receivers_shot_43
# 	source 44: ./out_for_pasha/receiver/receivers_shot_44
# 	source 45: ./out_for_pasha/receiver/receivers_shot_45
# 	source 46: ./out_for_pasha/receiver/receivers_shot_46
# 	source 47: ./out_for_pasha/receiver/receivers_shot_47
# 	source 48: ./out_for_pasha/receiver/receivers_shot_48
# 	source 49: ./out_for_pasha/receiver/receivers_shot_49
# 	source 50: ./out_for_pasha/receiver/receivers_shot_50
# 	source 51: ./out_for_pasha/receiver/receivers_shot_51
# 	source 52: ./out_for_pasha/receiver/receivers_shot_52
# 	source 53: ./out_for_pasha/receiver/receivers_shot_53
# 	source 54: ./out_for_pasha/receiver/receivers_shot_54
# 	source 55: ./out_for_pasha/receiver/receivers_shot_55
# 	source 56: ./out_for_pasha/receiver/receivers_shot_56
# 	source 57: ./out_for_pasha/receiver/receivers_shot_57
# 	source 58: ./out_for_pasha/receiver/receivers_shot_58
# 	source 59: ./out_for_pasha/receiver/receivers_shot_59
# 	source 60: ./out_for_pasha/receiver/receivers_shot_60
# 	source 61: ./out_for_pasha/receiver/receivers_shot_61
# 	source 62: ./out_for_pasha/receiver/receivers_shot_62
# 	source 63: ./out_for_pasha/receiver/receivers_shot_63
# 	source 64: ./out_for_pasha/receiver/receivers_shot_64
# 	source 65: ./out_for_pasha/receiver/receivers_shot_65
# 	source 66: ./out_for_pasha/receiver/receivers_shot_66
# 	source 67: ./out_for_pasha/receiver/receivers_shot_67
# 	source 68: ./out_for_pasha/receiver/receivers_shot_68
# 	source 69: ./out_for_pasha/receiver/receivers_shot_69
# 	source 70: ./out_for_pasha/receiver/receivers_shot_70
# 	source 71: ./out_for_pasha/receiver/receivers_shot_71
# 	source 72: ./out_for_pasha/receiver/receivers_shot_72
# 	source 73: ./out_for_pasha/receiver/receivers_shot_73
# 	source 74: ./out_for_pasha/receiver/receivers_shot_74
# 	source 75: ./out_for_pasha/receiver/receivers_shot_75
# 	source 76: ./out_for_pasha/receiver/receivers_shot_76
# 	source 77: ./out_for_pasha/receiver/receivers_shot_77
# 	source 78: ./out_for_pasha/receiver/receivers_shot_78
# 	source 79: ./out_for_pasha/receiver/receivers_shot_79
# 	source 80: ./out_for_pasha/receiver/receivers_shot_80
# Write wavelets, one for every shot.
# 	wavelet 1: ./out_for_pasha/wavelet/wavelet_shot_1.dat
# 	wavelet 2: ./out_for_pasha/wavelet/wavelet_shot_2.dat
# 	wavelet 3: ./out_for_pasha/wavelet/wavelet_shot_3.dat
# 	wavelet 4: ./out_for_pasha/wavelet/wavelet_shot_4.dat
# 	wavelet 5: ./out_for_pasha/wavelet/wavelet_shot_5.dat
# 	wavelet 6: ./out_for_pasha/wavelet/wavelet_shot_6.dat
# 	wavelet 7: ./out_for_pasha/wavelet/wavelet_shot_7.dat
# 	wavelet 8: ./out_for_pasha/wavelet/wavelet_shot_8.dat
# 	wavelet 9: ./out_for_pasha/wavelet/wavelet_shot_9.dat
# 	wavelet 10: ./out_for_pasha/wavelet/wavelet_shot_10.dat
# 	wavelet 11: ./out_for_pasha/wavelet/wavelet_shot_11.dat
# 	wavelet 12: ./out_for_pasha/wavelet/wavelet_shot_12.dat
# 	wavelet 13: ./out_for_pasha/wavelet/wavelet_shot_13.dat
# 	wavelet 14: ./out_for_pasha/wavelet/wavelet_shot_14.dat
# 	wavelet 15: ./out_for_pasha/wavelet/wavelet_shot_15.dat
# 	wavelet 16: ./out_for_pasha/wavelet/wavelet_shot_16.dat
# 	wavelet 17: ./out_for_pasha/wavelet/wavelet_shot_17.dat
# 	wavelet 18: ./out_for_pasha/wavelet/wavelet_shot_18.dat
# 	wavelet 19: ./out_for_pasha/wavelet/wavelet_shot_19.dat
# 	wavelet 20: ./out_for_pasha/wavelet/wavelet_shot_20.dat
# 	wavelet 21: ./out_for_pasha/wavelet/wavelet_shot_21.dat
# 	wavelet 22: ./out_for_pasha/wavelet/wavelet_shot_22.dat
# 	wavelet 23: ./out_for_pasha/wavelet/wavelet_shot_23.dat
# 	wavelet 24: ./out_for_pasha/wavelet/wavelet_shot_24.dat
# 	wavelet 25: ./out_for_pasha/wavelet/wavelet_shot_25.dat
# 	wavelet 26: ./out_for_pasha/wavelet/wavelet_shot_26.dat
# 	wavelet 27: ./out_for_pasha/wavelet/wavelet_shot_27.dat
# 	wavelet 28: ./out_for_pasha/wavelet/wavelet_shot_28.dat
# 	wavelet 29: ./out_for_pasha/wavelet/wavelet_shot_29.dat
# 	wavelet 30: ./out_for_pasha/wavelet/wavelet_shot_30.dat
# 	wavelet 31: ./out_for_pasha/wavelet/wavelet_shot_31.dat
# 	wavelet 32: ./out_for_pasha/wavelet/wavelet_shot_32.dat
# 	wavelet 33: ./out_for_pasha/wavelet/wavelet_shot_33.dat
# 	wavelet 34: ./out_for_pasha/wavelet/wavelet_shot_34.dat
# 	wavelet 35: ./out_for_pasha/wavelet/wavelet_shot_35.dat
# 	wavelet 36: ./out_for_pasha/wavelet/wavelet_shot_36.dat
# 	wavelet 37: ./out_for_pasha/wavelet/wavelet_shot_37.dat
# 	wavelet 38: ./out_for_pasha/wavelet/wavelet_shot_38.dat
# 	wavelet 39: ./out_for_pasha/wavelet/wavelet_shot_39.dat
# 	wavelet 40: ./out_for_pasha/wavelet/wavelet_shot_40.dat
# 	wavelet 41: ./out_for_pasha/wavelet/wavelet_shot_41.dat
# 	wavelet 42: ./out_for_pasha/wavelet/wavelet_shot_42.dat
# 	wavelet 43: ./out_for_pasha/wavelet/wavelet_shot_43.dat
# 	wavelet 44: ./out_for_pasha/wavelet/wavelet_shot_44.dat
# 	wavelet 45: ./out_for_pasha/wavelet/wavelet_shot_45.dat
# 	wavelet 46: ./out_for_pasha/wavelet/wavelet_shot_46.dat
# 	wavelet 47: ./out_for_pasha/wavelet/wavelet_shot_47.dat
# 	wavelet 48: ./out_for_pasha/wavelet/wavelet_shot_48.dat
# 	wavelet 49: ./out_for_pasha/wavelet/wavelet_shot_49.dat
# 	wavelet 50: ./out_for_pasha/wavelet/wavelet_shot_50.dat
# 	wavelet 51: ./out_for_pasha/wavelet/wavelet_shot_51.dat
# 	wavelet 52: ./out_for_pasha/wavelet/wavelet_shot_52.dat
# 	wavelet 53: ./out_for_pasha/wavelet/wavelet_shot_53.dat
# 	wavelet 54: ./out_for_pasha/wavelet/wavelet_shot_54.dat
# 	wavelet 55: ./out_for_pasha/wavelet/wavelet_shot_55.dat
# 	wavelet 56: ./out_for_pasha/wavelet/wavelet_shot_56.dat
# 	wavelet 57: ./out_for_pasha/wavelet/wavelet_shot_57.dat
# 	wavelet 58: ./out_for_pasha/wavelet/wavelet_shot_58.dat
# 	wavelet 59: ./out_for_pasha/wavelet/wavelet_shot_59.dat
# 	wavelet 60: ./out_for_pasha/wavelet/wavelet_shot_60.dat
# 	wavelet 61: ./out_for_pasha/wavelet/wavelet_shot_61.dat
# 	wavelet 62: ./out_for_pasha/wavelet/wavelet_shot_62.dat
# 	wavelet 63: ./out_for_pasha/wavelet/wavelet_shot_63.dat
# 	wavelet 64: ./out_for_pasha/wavelet/wavelet_shot_64.dat
# 	wavelet 65: ./out_for_pasha/wavelet/wavelet_shot_65.dat
# 	wavelet 66: ./out_for_pasha/wavelet/wavelet_shot_66.dat
# 	wavelet 67: ./out_for_pasha/wavelet/wavelet_shot_67.dat
# 	wavelet 68: ./out_for_pasha/wavelet/wavelet_shot_68.dat
# 	wavelet 69: ./out_for_pasha/wavelet/wavelet_shot_69.dat
# 	wavelet 70: ./out_for_pasha/wavelet/wavelet_shot_70.dat
# 	wavelet 71: ./out_for_pasha/wavelet/wavelet_shot_71.dat
# 	wavelet 72: ./out_for_pasha/wavelet/wavelet_shot_72.dat
# 	wavelet 73: ./out_for_pasha/wavelet/wavelet_shot_73.dat
# 	wavelet 74: ./out_for_pasha/wavelet/wavelet_shot_74.dat
# 	wavelet 75: ./out_for_pasha/wavelet/wavelet_shot_75.dat
# 	wavelet 76: ./out_for_pasha/wavelet/wavelet_shot_76.dat
# 	wavelet 77: ./out_for_pasha/wavelet/wavelet_shot_77.dat
# 	wavelet 78: ./out_for_pasha/wavelet/wavelet_shot_78.dat
# 	wavelet 79: ./out_for_pasha/wavelet/wavelet_shot_79.dat
# 	wavelet 80: ./out_for_pasha/wavelet/wavelet_shot_80.dat
# Start simulation for 80 sources. NT: 3000, DT: 0.002...wait
#
# mpirun -np 40 ../den/bin/denise  ./out_for_pasha/seis.inp ./out_for_pasha/seis_fwi.inp
#
# Done. 65.98613286018372 sec.
#
# Check results in ./out_for_pasha/su/

# %%
# d.save_folder = root_fwi

# %%
d.verbose = 0    # don't show redundant print outs

if d.DT is None:
    d.DT = 0.002
shots = d.get_shots(keys=['_p.'])

mpl.rcParams['figure.dpi']= 100
par_shot = {'vmin': -0.05, 'vmax': 0.05}
if shots:
    print(f'Read {len(shots)} shots {shots[0].shape} into list')
    for i in [int(np.floor(x)) for x in np.linspace(0, len(shots)-1, 5)]:
        try:
            shot_s = shots[i]
            shot_f = data_p[i, :, ::d.NDT]
            vis.plot_compare_stripes(shot_s, shot_f, pclip=0.0125, colorbar=False, dt=d.DT, dx=dx)
        except:
            print(f'Failed to fetch data for i={i}')
mpl.rcParams['figure.dpi']= 100
# Out:
# Read 80 shots (324, 3000) into list

# %%
# wavefield_amp_ratio
print(np.max(np.abs(shot_f)) / np.max(np.abs(shot_s)) )
# Out:
# 1.0000142123411118

# %% [markdown]
# # Compare syn and field

# %%
wavelets_s = []
wavelets_f = []
for i, shot in enumerate(shots):
    no, nt = 1, 500
    wavelets_s.append(shot[:no, :nt].copy())
    wavelets_f.append(data_p[i, :no, :nt:d.NDT].copy())
print(f'Total sources: {len(wavelets_f)}')
wavelets_s = np.concatenate(wavelets_s, 0)
wavelets_f = np.concatenate(wavelets_f, 0)

# !!! DO THIS IN FIELD DATA APPLICATION !!!
# THIS MAKES SYNTHETIC AND FIELD COMPARABLE
# OTHERWISE THERE IS INSANE AMPLITUDE MISMATCH
# wavelets_f /= np.max(wavelets_f)
# wavelets_f *= wavelets_s.max()

print('Syn wavelets:\t{}\t{:.2f}\t{:.2f}'.format(wavelets_s.shape, wavelets_s.min(), wavelets_s.max()))
print('Field wavelets:\t{}\t{:.2f}\t{:.2f}'.format(wavelets_f.shape, wavelets_f.min(), wavelets_f.max()))

vis.plot_wiggles([wavelets_f, wavelets_s], n=10, colors=['r', 'b'], legend=['Field', 'Syn'])
# Out:
# Total sources: 80
# Syn wavelets:	(80, 500)	-19284.29	26554.20
# Field wavelets:	(80, 500)	-16728.73	24865.97
# [0, 8, 17, 26, 35, 43, 52, 61, 70, 79]

# %%
if shots:
    tvec = np.arange(nt) * d.DT
    plt.figure(figsize=(6,3)); 
    trace_idx = 0
    plt.plot(tvec, wavelets_f[trace_idx,:], 'r', lw=2, label='Field')
    plt.plot(tvec, wavelets_s[trace_idx,:], 'b', lw=2, label='Syn')
    # plt.plot(tvec, _dplotted[0][0], 'r', lw=2, label='Field')
    # plt.plot(tvec, _dplotted[1][0], 'b', lw=2, label='Syn')
    plt.legend()
    plt.xlabel('Time, sec')
    vis.savefig('wavelet_syn_field.png')
# Out:
# Save /home/ovcharoo/Dropbox/WORK_HARD/low_elastic/tex/GEOPHYSICS_21/pic/wavelet_syn_field.png

# %% [markdown]
# # REPLACE FIELD DATA BY MARM DATA

# %%
# data_p = np.concatenate([np.expand_dims(s, 0) for s in shots], 0)
# print(data_p.shape)

# %%
data_p_backup = data_p.copy()
print(data_p_backup.shape, d.DT)
# Out:
# (80, 324, 3000) 0.002

# %% [markdown]
# Geometric spreading correction (not used)

# %%
geom = np.repeat(np.repeat(np.arange(1, data_p.shape[-1]+1)[np.newaxis, ...] * d.DT, data_p.shape[1], 0)[np.newaxis, ...], data_p.shape[0], 0) ** 0.5

# Overwrite by ones, so it is not used
geom = np.ones_like(geom)
data_p = data_p_backup * geom
# data_p = data_p_backup

# %%
# data_p = np.concatenate([np.expand_dims(s, 0) for s in shots], 0)
print(data_p.shape, data_p.min(), data_p.max())
dref = np.mean(data_p, 0)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
vis.plot_shot(dref, title='Field data', pclip=0.25, colorbar=True, ax=ax[0])
vis.plot_spectrum(dref, dt=0.002, fmax=10, title='Spectrum', ax=ax[1])
# Out:
# (80, 324, 3000) -36872.38619092324 29173.327396346955

# %% [markdown]
# ## Save field data to a new folder in /su/

# %%
def copy_su_from_to(path_from, path_to):
    """ Copy files matching *.su.* from one folder to another folder"""
    os.makedirs(path_to, exist_ok=True)
    su_files = glob.glob(path_from + '/*.su.*')
    su_files = [f for f in su_files if '.it' not in f]
    print(f'Found {len(su_files)} *.su.* files in {path_from}')

    commands = []
    print(f'Copy files from {path_from} to {path_to}')
    for f in su_files:
        commands.append(f'cp {f} {path_to}')
    with multiprocessing.Pool() as pool:
        pool.map(os.system, commands)

# %%
root_su_field = os.path.join(d._root_su, 'field/')
copy_su_from_to(d._root_su, root_su_field)
# Out:
# Found 80 *.su.* files in ./out_for_pasha/su
# Copy files from ./out_for_pasha/su to ./out_for_pasha/su/field/

# %%
def get_fnames_pattern(pattern):    
    fnames = natsorted(glob.glob(pattern))
    fnames = [f for f in fnames if '.it' not in f]
    print(f'{len(fnames)} files found in {pattern}')
    return fnames

fnames = get_fnames_pattern(root_su_field + '*.su.*')
# Out:
# 80 files found in ./out_for_pasha/su/field/*.su.*

# %% [markdown]
# # Write field data into created .su files

# %%
print(data_p.shape, geom.shape)
geom_slice = geom[0, ...]
# Out:
# (80, 324, 3000) (80, 324, 3000)

# %%
for i, f in enumerate(fnames):
    with segyio.su.open(f, "r+", endian='little', ignore_geometry=True) as dst:
        tmp = data_p[i, :, ::d.NDT] / geom_slice[..., ::d.NDT]
        dst.trace = tmp
        print(f, dst.tracecount, tmp.shape, end='\r')
# Out:
# /home/ovcharoo/work/env_torch/lib/python3.8/site-packages/segyio/utils.py:23: RuntimeWarning: Implicit conversion from float64 to float32 (narrowing)
#   warnings.warn(msg.format(x.dtype, dtype), RuntimeWarning)
# ./out_for_pasha/su/field/seis_p.su.shot80 324 (324, 3000)

# %%
wb_taper = np.where(model.vp < 1.01 * model.vp.min(), 1, 0)
vis.plot_model(wb_taper)

# %%
nx0 = 500
limits_vp = {'vmin': model.vp.min() / 1000, 'vmax': model.vp.max() / 1000}
vis.plot_log_model(model.vp, dx, nx0, nz0, src, log=wlog, log_location=log_location, **limits_vp)
mpl.rcParams['figure.dpi']= 100

# %% [markdown]
# ### Abstraction over initial model

# %%
model_init = copy.copy(model)
print(model_init)
# Out:
# vp:	(152, 944), 1490.0000, 2929.2909 m/s
#
# vs:	(152, 944), 0.0000, 1691.2269 m/s
#
# rho:	(152, 944), 1000.0000, 2207.0485 m/s
#
# dx:	25.0000
# Size:
# 	OX:	min 0.0000	max 23575.0000 m
# Size:
# 	OZ:	min 0.0000	max 3775.0000 m

# %%
print(wlog.shape, vp.shape)

fig, ax = plt.subplots(1,1)
ax.plot(wlog)
ax.plot(vp[-len(wlog):, log_idx])
# Out:
# (116, 1) (152, 944)

# %% [markdown]
# # Full-waveform inversion
# Invert for elastic properties `vp`, `vs` and `rho`, given `x` and `y` velocity components of wavefield

# %% [markdown]
# ## Initial velocity model
# Smooth background model with true water bottom and shallow sediments

# %%
# ax = plot_model(np.concatenate((model_init.vp, model_init.vs, model_init.rho), 1))
# plot_logs(model_log, model_init, log_idx)
print(dx)
fig, ax = plt.subplots(1,1); 
ax_depth = np.arange(len(wlog)) * dx / 1000
# ax_depth = np.arange(len(log_linear)) * dx / 1000
ax.plot(ax_depth, wlog[::-1] / 1000, 'k', label='Well')
ax.plot(ax_depth, log[::-1] / 1000, 'k--', label='Ideal initial')

# log_pred = model_init.vp[-len(wlog):, log_idx]

log_pred = model_init.vp[-len(log):, log_idx]
ax.plot(ax_depth, log_pred[::-1] / 1000, 'r', label='Predicted initial')

nwater = 33#33
dummy = np.zeros_like(model.vp)
dummy[-nwater:, :] = 1.
log_taper = np.min(log_pred) + dummy[:, log_idx] * (np.max(log_pred) - np.min(log_pred))
log_taper = np.min(log_pred) + wb_taper[-len(wlog):, log_idx] * (np.max(log_pred) - np.min(log_pred))
# ax.plot(ax_depth, log_taper[::-1]  / 1000, 'b', label='Taper')
# 
# ax.plot(ax_depth, log_linear[::-1] / 1000, 'k--', label='Linear')
ax.set_ylabel('Velocity, km/s')
ax.set_xlabel('Depth, km')
ax.grid(True)
ax.legend()

print(len(wlog), model_init.vp.shape, len(model_init.vp[:len(wlog)]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c7567832200> in <module>
#       1 # ax = plot_model(np.concatenate((model_init.vp, model_init.vs, model_init.rho), 1))
#       2 # plot_logs(model_log, model_init, log_idx)
# ----> 3 print(dx)
#       4 fig, ax = plt.subplots(1,1);
#       5 ax_depth = np.arange(len(wlog)) * dx / 1000
#
# NameError: name 'dx' is not defined

# %%
plot_logs(model_log, model_init, log_idx)

# %% [markdown]
# ## Stages of inversion
# Use default parameters, except high- and low-pass corner frequencies of Butterworth filter

# %%
d.SWS_TAPER_GRAD_HOR = 1
d.GRADT1, d.GRADT2 = 25, 30

# %%
# # Turn off if it breaks something
# d.SCALEFAC = 1.5     # reduce step by this
# d.EPS_SCALE = 0.01   # eps_scale * dgrad/dm

# %%
# import loaders as ld
# # Gradient tapering
# d.SWS_TAPER_GRAD_VERT = 0
# d.SWS_TAPER_CIRCULAR_PER_SHOT = 0   # enable grad tapering around sources

d.VPUPPERLIM = 3000.
d.VPLOWERLIM = np.min(model_init.vp)
d.VSUPPERLIM = 2500.
d.VSLOWERLIM = np.min(model_init.vs)
d.RHOUPPERLIM = 2500.
d.RHOLOWERLIM = np.min(model_init.rho)

d.SWS_TAPER_FILE = 1

taper = np.zeros_like(model_init.vp)
print(taper.shape,wb_taper.shape)
shift = 4
# shift = 8
taper[shift:, :] = wb_taper[:-shift,:] # water mask
# taper[-nwater:, :] = 1.
# taper[-28:, :] = 1.
# taper[:, 650:] = 1.
# taper[:,-10:] = 1. # right
# taper[:,:10] = 1. # left
# taper[:5,:] = 1. # bottom
# nwater= 30 - shift
# taper[-nwater:, :] = 1.

# plt.imshow(taper)
if d.SWS_TAPER_FILE:
    os.makedirs(d._root_tapers, exist_ok=True)
    ld.write_bin(np.fliplr((1 - taper.astype(np.float32).T)), os.path.join(d._root_tapers, 'taper.bin'))
    ld.write_bin(np.fliplr((1 - taper.astype(np.float32).T)), os.path.join(d._root_tapers, 'taper_u.bin'))
    ld.write_bin(np.fliplr((1 - taper.astype(np.float32).T)), os.path.join(d._root_tapers, 'taper_rho.bin'))
    vis.plot_acquisition(taper, dx, src, rec)
# Out:
# (152, 944) (152, 944)
# Save (944, 152) as binary to ./out_for_pasha/taper/taper.bin
# Save (944, 152) as binary to ./out_for_pasha/taper/taper_u.bin
# Save (944, 152) as binary to ./out_for_pasha/taper/taper_rho.bin

# %% [markdown]
# ## Run inversion

# %%
par_stages_fwi = {'inv_vs_iter': 0,
                 'inv_rho_iter': 0,
                 'normalize': 2,
                 'order': 6,
                 }

d.fwi_stages = []
freqs_high = [3, 4, 5, 6, 7]
grad_smoothing = [2, 1.5, 0.5, 0.25, 0.125]
lnorms = [2, 2, 2, 2, 2, 2]
spatfilters = [4, 4, 0, 0, 0, 0]
for i, freq in enumerate(freqs_high):
    d.add_fwi_stage(fc_high=freq, 
                    wd_damp=grad_smoothing[i],
                    wd_damp1=grad_smoothing[i],
                    lnorm=lnorms[i],
                    spatfilter=spatfilters[i],
                    **par_stages_fwi)
    print(f'Stage {i+1}:\n\t{d.fwi_stages[i]}\n')
# Out:
# Stage 1:
# 	{'PRO': 0.01, 'TIME_FILT': 1, 'FC_LOW': 0.0, 'FC_HIGH': 3, 'ORDER': 6, 'TIME_WIN': 0, 'GAMMA': 20, 'TWIN-': 0.0, 'TWIN+': 0.0, 'INV_VP_ITER': 0, 'INV_VS_ITER': 0, 'INV_RHO_ITER': 0, 'INV_QS_ITER': 0, 'SPATFILTER': 4, 'WD_DAMP': 2, 'WD_DAMP1': 2, 'EPRECOND': 3, 'LNORM': 2, 'ROWI': 0, 'STF_INV': 0, 'OFFSETC_STF': -4.0, 'EPS_STF': 0.1, 'NORMALIZE': 2, 'OFFSET_MUTE': 0, 'OFFSETC': 10, 'SCALERHO': 0.5, 'SCALEQS': 1.0, 'ENV': 1, 'N_ORDER': 0}
#
# Stage 2:
# 	{'PRO': 0.01, 'TIME_FILT': 1, 'FC_LOW': 0.0, 'FC_HIGH': 4, 'ORDER': 6, 'TIME_WIN': 0, 'GAMMA': 20, 'TWIN-': 0.0, 'TWIN+': 0.0, 'INV_VP_ITER': 0, 'INV_VS_ITER': 0, 'INV_RHO_ITER': 0, 'INV_QS_ITER': 0, 'SPATFILTER': 4, 'WD_DAMP': 1.5, 'WD_DAMP1': 1.5, 'EPRECOND': 3, 'LNORM': 2, 'ROWI': 0, 'STF_INV': 0, 'OFFSETC_STF': -4.0, 'EPS_STF': 0.1, 'NORMALIZE': 2, 'OFFSET_MUTE': 0, 'OFFSETC': 10, 'SCALERHO': 0.5, 'SCALEQS': 1.0, 'ENV': 1, 'N_ORDER': 0}
#
# Stage 3:
# 	{'PRO': 0.01, 'TIME_FILT': 1, 'FC_LOW': 0.0, 'FC_HIGH': 5, 'ORDER': 6, 'TIME_WIN': 0, 'GAMMA': 20, 'TWIN-': 0.0, 'TWIN+': 0.0, 'INV_VP_ITER': 0, 'INV_VS_ITER': 0, 'INV_RHO_ITER': 0, 'INV_QS_ITER': 0, 'SPATFILTER': 0, 'WD_DAMP': 0.5, 'WD_DAMP1': 0.5, 'EPRECOND': 3, 'LNORM': 2, 'ROWI': 0, 'STF_INV': 0, 'OFFSETC_STF': -4.0, 'EPS_STF': 0.1, 'NORMALIZE': 2, 'OFFSET_MUTE': 0, 'OFFSETC': 10, 'SCALERHO': 0.5, 'SCALEQS': 1.0, 'ENV': 1, 'N_ORDER': 0}
#
# Stage 4:
# 	{'PRO': 0.01, 'TIME_FILT': 1, 'FC_LOW': 0.0, 'FC_HIGH': 6, 'ORDER': 6, 'TIME_WIN': 0, 'GAMMA': 20, 'TWIN-': 0.0, 'TWIN+': 0.0, 'INV_VP_ITER': 0, 'INV_VS_ITER': 0, 'INV_RHO_ITER': 0, 'INV_QS_ITER': 0, 'SPATFILTER': 0, 'WD_DAMP': 0.25, 'WD_DAMP1': 0.25, 'EPRECOND': 3, 'LNORM': 2, 'ROWI': 0, 'STF_INV': 0, 'OFFSETC_STF': -4.0, 'EPS_STF': 0.1, 'NORMALIZE': 2, 'OFFSET_MUTE': 0, 'OFFSETC': 10, 'SCALERHO': 0.5, 'SCALEQS': 1.0, 'ENV': 1, 'N_ORDER': 0}
#
# Stage 5:
# 	{'PRO': 0.01, 'TIME_FILT': 1, 'FC_LOW': 0.0, 'FC_HIGH': 7, 'ORDER': 6, 'TIME_WIN': 0, 'GAMMA': 20, 'TWIN-': 0.0, 'TWIN+': 0.0, 'INV_VP_ITER': 0, 'INV_VS_ITER': 0, 'INV_RHO_ITER': 0, 'INV_QS_ITER': 0, 'SPATFILTER': 0, 'WD_DAMP': 0.125, 'WD_DAMP1': 0.125, 'EPRECOND': 3, 'LNORM': 2, 'ROWI': 0, 'STF_INV': 0, 'OFFSETC_STF': -4.0, 'EPS_STF': 0.1, 'NORMALIZE': 2, 'OFFSET_MUTE': 0, 'OFFSETC': 10, 'SCALERHO': 0.5, 'SCALEQS': 1.0, 'ENV': 1, 'N_ORDER': 0}

# %%
d.DATA_DIR = f'{root_fwi}su/field/seis'

# %%
d.WRITE_STF = 0
d.NPROCX = 8
d.NPROCY = 2
d.verbose = 1
par_fwi_runtime = {'run_command': 'mpirun -np 32', 'disable': True}

# %% [markdown]
# **FWI is disabled!** It only writes file to the `root_fwi` folder.
#
# **Copy this folder to Shaheen**, set 40 nodes and 1h runtime

# %%
d.fwi(model_init, src, rec, **par_fwi_runtime)
# Out:
# Target data: ./out_for_pasha/su/field/seis
# Create FWI workflow file in ./out_for_pasha/seis_fwi.inp
# Init model:
# 	152 x 944, dx = 25.0 m
# Check max source frequency:
# 	min Vs: 931.1580816910116 m/s
# 	min Vp: 1490.0 m/s
# 	Number of gridpoints per minimum wavelength = 3.69
# 	Maximum source wavelet frequency = 10.093854544076006 Hz
# Check domain decomposition for parallelization:
# 	in X-direction, NX % NPROCX, 944 % 8 = 0
# 	in Y-direction, NY % NPROCY, 152 % 2 = 0
# Write ./out_for_pasha/start/model.vp
# Write ./out_for_pasha/start/model.vs
# Write ./out_for_pasha/start/model.rho
# Custom taper from taper.bin (vp), taper_u.bin (vs) and taper_rho.bin (rho)
# Enable streamer mode!
# 	source 1: ./out_for_pasha/receiver/receivers_shot_1
# 	source 2: ./out_for_pasha/receiver/receivers_shot_2
# 	source 3: ./out_for_pasha/receiver/receivers_shot_3
# 	source 4: ./out_for_pasha/receiver/receivers_shot_4
# 	source 5: ./out_for_pasha/receiver/receivers_shot_5
# 	source 6: ./out_for_pasha/receiver/receivers_shot_6
# 	source 7: ./out_for_pasha/receiver/receivers_shot_7
# 	source 8: ./out_for_pasha/receiver/receivers_shot_8
# 	source 9: ./out_for_pasha/receiver/receivers_shot_9
# 	source 10: ./out_for_pasha/receiver/receivers_shot_10
# 	source 11: ./out_for_pasha/receiver/receivers_shot_11
# 	source 12: ./out_for_pasha/receiver/receivers_shot_12
# 	source 13: ./out_for_pasha/receiver/receivers_shot_13
# 	source 14: ./out_for_pasha/receiver/receivers_shot_14
# 	source 15: ./out_for_pasha/receiver/receivers_shot_15
# 	source 16: ./out_for_pasha/receiver/receivers_shot_16
# 	source 17: ./out_for_pasha/receiver/receivers_shot_17
# 	source 18: ./out_for_pasha/receiver/receivers_shot_18
# 	source 19: ./out_for_pasha/receiver/receivers_shot_19
# 	source 20: ./out_for_pasha/receiver/receivers_shot_20
# 	source 21: ./out_for_pasha/receiver/receivers_shot_21
# 	source 22: ./out_for_pasha/receiver/receivers_shot_22
# 	source 23: ./out_for_pasha/receiver/receivers_shot_23
# 	source 24: ./out_for_pasha/receiver/receivers_shot_24
# 	source 25: ./out_for_pasha/receiver/receivers_shot_25
# 	source 26: ./out_for_pasha/receiver/receivers_shot_26
# 	source 27: ./out_for_pasha/receiver/receivers_shot_27
# 	source 28: ./out_for_pasha/receiver/receivers_shot_28
# 	source 29: ./out_for_pasha/receiver/receivers_shot_29
# 	source 30: ./out_for_pasha/receiver/receivers_shot_30
# 	source 31: ./out_for_pasha/receiver/receivers_shot_31
# 	source 32: ./out_for_pasha/receiver/receivers_shot_32
# 	source 33: ./out_for_pasha/receiver/receivers_shot_33
# 	source 34: ./out_for_pasha/receiver/receivers_shot_34
# 	source 35: ./out_for_pasha/receiver/receivers_shot_35
# 	source 36: ./out_for_pasha/receiver/receivers_shot_36
# 	source 37: ./out_for_pasha/receiver/receivers_shot_37
# 	source 38: ./out_for_pasha/receiver/receivers_shot_38
# 	source 39: ./out_for_pasha/receiver/receivers_shot_39
# 	source 40: ./out_for_pasha/receiver/receivers_shot_40
# 	source 41: ./out_for_pasha/receiver/receivers_shot_41
# 	source 42: ./out_for_pasha/receiver/receivers_shot_42
# 	source 43: ./out_for_pasha/receiver/receivers_shot_43
# 	source 44: ./out_for_pasha/receiver/receivers_shot_44
# 	source 45: ./out_for_pasha/receiver/receivers_shot_45
# 	source 46: ./out_for_pasha/receiver/receivers_shot_46
# 	source 47: ./out_for_pasha/receiver/receivers_shot_47
# 	source 48: ./out_for_pasha/receiver/receivers_shot_48
# 	source 49: ./out_for_pasha/receiver/receivers_shot_49
# 	source 50: ./out_for_pasha/receiver/receivers_shot_50
# 	source 51: ./out_for_pasha/receiver/receivers_shot_51
# 	source 52: ./out_for_pasha/receiver/receivers_shot_52
# 	source 53: ./out_for_pasha/receiver/receivers_shot_53
# 	source 54: ./out_for_pasha/receiver/receivers_shot_54
# 	source 55: ./out_for_pasha/receiver/receivers_shot_55
# 	source 56: ./out_for_pasha/receiver/receivers_shot_56
# 	source 57: ./out_for_pasha/receiver/receivers_shot_57
# 	source 58: ./out_for_pasha/receiver/receivers_shot_58
# 	source 59: ./out_for_pasha/receiver/receivers_shot_59
# 	source 60: ./out_for_pasha/receiver/receivers_shot_60
# 	source 61: ./out_for_pasha/receiver/receivers_shot_61
# 	source 62: ./out_for_pasha/receiver/receivers_shot_62
# 	source 63: ./out_for_pasha/receiver/receivers_shot_63
# 	source 64: ./out_for_pasha/receiver/receivers_shot_64
# 	source 65: ./out_for_pasha/receiver/receivers_shot_65
# 	source 66: ./out_for_pasha/receiver/receivers_shot_66
# 	source 67: ./out_for_pasha/receiver/receivers_shot_67
# 	source 68: ./out_for_pasha/receiver/receivers_shot_68
# 	source 69: ./out_for_pasha/receiver/receivers_shot_69
# 	source 70: ./out_for_pasha/receiver/receivers_shot_70
# 	source 71: ./out_for_pasha/receiver/receivers_shot_71
# 	source 72: ./out_for_pasha/receiver/receivers_shot_72
# 	source 73: ./out_for_pasha/receiver/receivers_shot_73
# 	source 74: ./out_for_pasha/receiver/receivers_shot_74
# 	source 75: ./out_for_pasha/receiver/receivers_shot_75
# 	source 76: ./out_for_pasha/receiver/receivers_shot_76
# 	source 77: ./out_for_pasha/receiver/receivers_shot_77
# 	source 78: ./out_for_pasha/receiver/receivers_shot_78
# 	source 79: ./out_for_pasha/receiver/receivers_shot_79
# 	source 80: ./out_for_pasha/receiver/receivers_shot_80
# Write wavelets, one for every shot.
# 	wavelet 1: ./out_for_pasha/wavelet/wavelet_shot_1.dat
# 	wavelet 2: ./out_for_pasha/wavelet/wavelet_shot_2.dat
# 	wavelet 3: ./out_for_pasha/wavelet/wavelet_shot_3.dat
# 	wavelet 4: ./out_for_pasha/wavelet/wavelet_shot_4.dat
# 	wavelet 5: ./out_for_pasha/wavelet/wavelet_shot_5.dat
# 	wavelet 6: ./out_for_pasha/wavelet/wavelet_shot_6.dat
# 	wavelet 7: ./out_for_pasha/wavelet/wavelet_shot_7.dat
# 	wavelet 8: ./out_for_pasha/wavelet/wavelet_shot_8.dat
# 	wavelet 9: ./out_for_pasha/wavelet/wavelet_shot_9.dat
# 	wavelet 10: ./out_for_pasha/wavelet/wavelet_shot_10.dat
# 	wavelet 11: ./out_for_pasha/wavelet/wavelet_shot_11.dat
# 	wavelet 12: ./out_for_pasha/wavelet/wavelet_shot_12.dat
# 	wavelet 13: ./out_for_pasha/wavelet/wavelet_shot_13.dat
# 	wavelet 14: ./out_for_pasha/wavelet/wavelet_shot_14.dat
# 	wavelet 15: ./out_for_pasha/wavelet/wavelet_shot_15.dat
# 	wavelet 16: ./out_for_pasha/wavelet/wavelet_shot_16.dat
# 	wavelet 17: ./out_for_pasha/wavelet/wavelet_shot_17.dat
# 	wavelet 18: ./out_for_pasha/wavelet/wavelet_shot_18.dat
# 	wavelet 19: ./out_for_pasha/wavelet/wavelet_shot_19.dat
# 	wavelet 20: ./out_for_pasha/wavelet/wavelet_shot_20.dat
# 	wavelet 21: ./out_for_pasha/wavelet/wavelet_shot_21.dat
# 	wavelet 22: ./out_for_pasha/wavelet/wavelet_shot_22.dat
# 	wavelet 23: ./out_for_pasha/wavelet/wavelet_shot_23.dat
# 	wavelet 24: ./out_for_pasha/wavelet/wavelet_shot_24.dat
# 	wavelet 25: ./out_for_pasha/wavelet/wavelet_shot_25.dat
# 	wavelet 26: ./out_for_pasha/wavelet/wavelet_shot_26.dat
# 	wavelet 27: ./out_for_pasha/wavelet/wavelet_shot_27.dat
# 	wavelet 28: ./out_for_pasha/wavelet/wavelet_shot_28.dat
# 	wavelet 29: ./out_for_pasha/wavelet/wavelet_shot_29.dat
# 	wavelet 30: ./out_for_pasha/wavelet/wavelet_shot_30.dat
# 	wavelet 31: ./out_for_pasha/wavelet/wavelet_shot_31.dat
# 	wavelet 32: ./out_for_pasha/wavelet/wavelet_shot_32.dat
# 	wavelet 33: ./out_for_pasha/wavelet/wavelet_shot_33.dat
# 	wavelet 34: ./out_for_pasha/wavelet/wavelet_shot_34.dat
# 	wavelet 35: ./out_for_pasha/wavelet/wavelet_shot_35.dat
# 	wavelet 36: ./out_for_pasha/wavelet/wavelet_shot_36.dat
# 	wavelet 37: ./out_for_pasha/wavelet/wavelet_shot_37.dat
# 	wavelet 38: ./out_for_pasha/wavelet/wavelet_shot_38.dat
# 	wavelet 39: ./out_for_pasha/wavelet/wavelet_shot_39.dat
# 	wavelet 40: ./out_for_pasha/wavelet/wavelet_shot_40.dat
# 	wavelet 41: ./out_for_pasha/wavelet/wavelet_shot_41.dat
# 	wavelet 42: ./out_for_pasha/wavelet/wavelet_shot_42.dat
# 	wavelet 43: ./out_for_pasha/wavelet/wavelet_shot_43.dat
# 	wavelet 44: ./out_for_pasha/wavelet/wavelet_shot_44.dat
# 	wavelet 45: ./out_for_pasha/wavelet/wavelet_shot_45.dat
# 	wavelet 46: ./out_for_pasha/wavelet/wavelet_shot_46.dat
# 	wavelet 47: ./out_for_pasha/wavelet/wavelet_shot_47.dat
# 	wavelet 48: ./out_for_pasha/wavelet/wavelet_shot_48.dat
# 	wavelet 49: ./out_for_pasha/wavelet/wavelet_shot_49.dat
# 	wavelet 50: ./out_for_pasha/wavelet/wavelet_shot_50.dat
# 	wavelet 51: ./out_for_pasha/wavelet/wavelet_shot_51.dat
# 	wavelet 52: ./out_for_pasha/wavelet/wavelet_shot_52.dat
# 	wavelet 53: ./out_for_pasha/wavelet/wavelet_shot_53.dat
# 	wavelet 54: ./out_for_pasha/wavelet/wavelet_shot_54.dat
# 	wavelet 55: ./out_for_pasha/wavelet/wavelet_shot_55.dat
# 	wavelet 56: ./out_for_pasha/wavelet/wavelet_shot_56.dat
# 	wavelet 57: ./out_for_pasha/wavelet/wavelet_shot_57.dat
# 	wavelet 58: ./out_for_pasha/wavelet/wavelet_shot_58.dat
# 	wavelet 59: ./out_for_pasha/wavelet/wavelet_shot_59.dat
# 	wavelet 60: ./out_for_pasha/wavelet/wavelet_shot_60.dat
# 	wavelet 61: ./out_for_pasha/wavelet/wavelet_shot_61.dat
# 	wavelet 62: ./out_for_pasha/wavelet/wavelet_shot_62.dat
# 	wavelet 63: ./out_for_pasha/wavelet/wavelet_shot_63.dat
# 	wavelet 64: ./out_for_pasha/wavelet/wavelet_shot_64.dat
# 	wavelet 65: ./out_for_pasha/wavelet/wavelet_shot_65.dat
# 	wavelet 66: ./out_for_pasha/wavelet/wavelet_shot_66.dat
# 	wavelet 67: ./out_for_pasha/wavelet/wavelet_shot_67.dat
# 	wavelet 68: ./out_for_pasha/wavelet/wavelet_shot_68.dat
# 	wavelet 69: ./out_for_pasha/wavelet/wavelet_shot_69.dat
# 	wavelet 70: ./out_for_pasha/wavelet/wavelet_shot_70.dat
# 	wavelet 71: ./out_for_pasha/wavelet/wavelet_shot_71.dat
# 	wavelet 72: ./out_for_pasha/wavelet/wavelet_shot_72.dat
# 	wavelet 73: ./out_for_pasha/wavelet/wavelet_shot_73.dat
# 	wavelet 74: ./out_for_pasha/wavelet/wavelet_shot_74.dat
# 	wavelet 75: ./out_for_pasha/wavelet/wavelet_shot_75.dat
# 	wavelet 76: ./out_for_pasha/wavelet/wavelet_shot_76.dat
# 	wavelet 77: ./out_for_pasha/wavelet/wavelet_shot_77.dat
# 	wavelet 78: ./out_for_pasha/wavelet/wavelet_shot_78.dat
# 	wavelet 79: ./out_for_pasha/wavelet/wavelet_shot_79.dat
# 	wavelet 80: ./out_for_pasha/wavelet/wavelet_shot_80.dat
# Start simulation for 80 sources. NT: 3000, DT: 0.002...wait
#
# Disabled. Run in terminal:
# 	mpirun -np 32 ../den/bin/denise  ./out_for_pasha/seis.inp ./out_for_pasha/seis_fwi.inp

# %% [markdown]
# ### Visualize FWI outputs
# It will not hurt to make sure that paths and model dims are up to date. This is necessary when you only want to plot pictures, without running modeling or FWI

# %%
d.set_model(model_init)
print(d.save_folder)
# Out:
# Init model:
# 	152 x 944, dx = 25.0 m
# ./out_cgg_hard_log3_long/

# %% [markdown]
# ### Inverted model
# The code ouputs inverted models for every elastic property at every FWI stage. Change `vp` to `vs` or `rho` to explore respective outputs

# %%
mpl.rcParams['figure.dpi']= 300
d.verbose = 2

models, fnames = d.get_fwi_models(['vp', 'stage'], return_filenames=True)
for m, f in zip(models, fnames):
    vis.plot_log_model(m, dx, nx0, nz0, src, log=wlog, log_location=log_location, **limits_vp)
mpl.rcParams['figure.dpi']= 100
# Out:
# Parse files from ./out_for_pasha/model which contain ['vp', 'stage']
# No files found! Exception raised.

# %% [markdown]
# ### Well-logs
# Plot logs in true model (dashed) and inverted models (solid) for every inversion stage

# %%
# Load inverted models from all stages
vvr = {'vp': None, 'vs': None, 'rho': None}
for k in vvr.keys():
    vvr[k], fnames = d.get_fwi_models([k + '_stage'], return_filenames=True)

for i in range(len(vvr['vp'])):
    plot_logs(model_log, api.Model(vvr['vp'][i], vvr['vs'][i], vvr['rho'][i], dx), log_idx)
# Out:
# Parse files from ./out_for_pasha/model which contain ['vp_stage']
# No files found! Exception raised.
# Parse files from ./out_for_pasha/model which contain ['vs_stage']
# No files found! Exception raised.
# Parse files from ./out_for_pasha/model which contain ['rho_stage']
# No files found! Exception raised.

# %% [markdown]
# ### Gradients

# %%
d.verbose = 0
grads, fnames = d.get_fwi_gradients(return_filenames=True)
for g, f in zip(grads, fnames):
    plot_model(g, f)

# %%
# d.help()

# %%
def get_model_last():
    all_fnames = []
    vps, fnames = d.get_fwi_models(['vp', 'stage'], return_filenames=True)
    all_fnames += fnames
    vss, fnames = d.get_fwi_models(['vs', 'stage'], return_filenames=True)
    all_fnames += fnames
    rhos, fnames = d.get_fwi_models(['rho', 'stage'], return_filenames=True)
    all_fnames += fnames

    if all_fnames:
        for f in all_fnames:
            if not f.split('/')[-1] in os.listdir(f'{root_fwi}start/'):
                command = f'cp {f} {root_fwi}start/'
                print(command)
                os.system(command)

    if vps:
        print(f'Init new starting model from {fnames[-1]}')
        model_last = api.Model(vps[-1], vss[-1], rhos[-1], dx)
    return model_last

model_last = get_model_last()
# Out:
# Read models from ./out_for_pasha/model with ['vp', 'stage']
# Read models from ./out_for_pasha/model with ['vs', 'stage']
# Read models from ./out_for_pasha/model with ['rho', 'stage']
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-68-cdfadad6ddc1> in <module>
#      20     return model_last
#      21
# ---> 22 model_last = get_model_last()
#
# <ipython-input-68-cdfadad6ddc1> in get_model_last()
#      18         print(f'Init new starting model from {fnames[-1]}')
#      19         model_last = api.Model(vps[-1], vss[-1], rhos[-1], dx)
# ---> 20     return model_last
#      21
#      22 model_last = get_model_last()
#
# UnboundLocalError: local variable 'model_last' referenced before assignment

# %%
vis.plot_model(model_last.vp / 1000, **limits_vp)

# %% [markdown]
# # Compare wavefiedls before/after

# %%
vps, fnames = d.get_fwi_models(['vp_stage'], return_filenames=True)
vss, fnames = d.get_fwi_models(['vs_stage'], return_filenames=True)
rhos, fnames = d.get_fwi_models(['rho_stage'], return_filenames=True)

if vps:
    model_last = api.Model(vps[-1], vss[-1], rhos[-1], dx)
    print(f'Found last model at {fnames[-1]}')
else:
    print(f'Not found the inverted model in {d.save_folder}!')
# Out:
# Read models from ./out_cgg_hard_log3_long/model with ['vp_stage']
# < ./out_cgg_hard_log3_long/model/modelTest_vp_stage_1.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vp_stage_2.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vp_stage_3.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vp_stage_4.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vp_stage_5.bin > np.array((944, 152))
# Read models from ./out_cgg_hard_log3_long/model with ['vs_stage']
# < ./out_cgg_hard_log3_long/model/modelTest_vs_stage_1.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vs_stage_2.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vs_stage_3.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vs_stage_4.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_vs_stage_5.bin > np.array((944, 152))
# Read models from ./out_cgg_hard_log3_long/model with ['rho_stage']
# < ./out_cgg_hard_log3_long/model/modelTest_rho_stage_1.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_rho_stage_2.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_rho_stage_3.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_rho_stage_4.bin > np.array((944, 152))
# < ./out_cgg_hard_log3_long/model/modelTest_rho_stage_5.bin > np.array((944, 152))
# Found last model at ./out_cgg_hard_log3_long/model/modelTest_rho_stage_5.bin

# %%
d.save_folder = root_fwi[:-1] + '_wavefield/'
print(f'{root_fwi[:-1]} --> {d.save_folder}')
# Out:
# ./out_cgg_hard_log3_long --> ./out_cgg_hard_log3_long_wavefield/

# %%
print(par_forward)
# Out:
# {'run_command': 'mpirun -np 40', 'disable': False}

# %%
d.NPROCX = 1
d.NPROCY = 1
d.forward(model_last, src, rec, **par_forward)
# Out:
# Current directory is /home/ovcharoo/work/nb12_pearson
# Init paths at ./out_cgg_hard_log3_long_wavefield/
# Init model:
# 	152 x 944, dx = 25.0 m
# Check max source frequency:
# 	min Vs: 444.4956359863281 m/s
# 	min Vp: 1490.0 m/s
# 	Number of gridpoints per minimum wavelength = 3.69
# 	Maximum source wavelet frequency = 4.818380877900576 Hz
# Check domain decomposition for parallelization:
# 	in X-direction, NX % NPROCX, 944 % 1 = 0
# 	in Y-direction, NY % NPROCY, 152 % 1 = 0
# Write ./out_cgg_hard_log3_long_wavefield/start/model.vp
# Write ./out_cgg_hard_log3_long_wavefield/start/model.vs
# Write ./out_cgg_hard_log3_long_wavefield/start/model.rho
# Custom taper from taper.bin (vp), taper_u.bin (vs) and taper_rho.bin (rho)
# Enable streamer mode!
# 	source 1: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_1
# 	source 2: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_2
# 	source 3: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_3
# 	source 4: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_4
# 	source 5: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_5
# 	source 6: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_6
# 	source 7: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_7
# 	source 8: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_8
# 	source 9: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_9
# 	source 10: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_10
# 	source 11: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_11
# 	source 12: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_12
# 	source 13: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_13
# 	source 14: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_14
# 	source 15: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_15
# 	source 16: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_16
# 	source 17: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_17
# 	source 18: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_18
# 	source 19: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_19
# 	source 20: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_20
# 	source 21: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_21
# 	source 22: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_22
# 	source 23: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_23
# 	source 24: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_24
# 	source 25: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_25
# 	source 26: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_26
# 	source 27: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_27
# 	source 28: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_28
# 	source 29: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_29
# 	source 30: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_30
# 	source 31: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_31
# 	source 32: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_32
# 	source 33: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_33
# 	source 34: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_34
# 	source 35: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_35
# 	source 36: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_36
# 	source 37: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_37
# 	source 38: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_38
# 	source 39: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_39
# 	source 40: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_40
# 	source 41: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_41
# 	source 42: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_42
# 	source 43: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_43
# 	source 44: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_44
# 	source 45: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_45
# 	source 46: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_46
# 	source 47: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_47
# 	source 48: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_48
# 	source 49: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_49
# 	source 50: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_50
# 	source 51: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_51
# 	source 52: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_52
# 	source 53: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_53
# 	source 54: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_54
# 	source 55: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_55
# 	source 56: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_56
# 	source 57: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_57
# 	source 58: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_58
# 	source 59: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_59
# 	source 60: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_60
# 	source 61: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_61
# 	source 62: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_62
# 	source 63: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_63
# 	source 64: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_64
# 	source 65: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_65
# 	source 66: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_66
# 	source 67: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_67
# 	source 68: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_68
# 	source 69: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_69
# 	source 70: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_70
# 	source 71: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_71
# 	source 72: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_72
# 	source 73: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_73
# 	source 74: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_74
# 	source 75: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_75
# 	source 76: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_76
# 	source 77: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_77
# 	source 78: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_78
# 	source 79: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_79
# 	source 80: ./out_cgg_hard_log3_long_wavefield/receiver/receivers_shot_80
# Write wavelets, one for every shot.
# 	wavelet 1: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_1.dat
# 	wavelet 2: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_2.dat
# 	wavelet 3: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_3.dat
# 	wavelet 4: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_4.dat
# 	wavelet 5: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_5.dat
# 	wavelet 6: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_6.dat
# 	wavelet 7: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_7.dat
# 	wavelet 8: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_8.dat
# 	wavelet 9: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_9.dat
# 	wavelet 10: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_10.dat
# 	wavelet 11: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_11.dat
# 	wavelet 12: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_12.dat
# 	wavelet 13: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_13.dat
# 	wavelet 14: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_14.dat
# 	wavelet 15: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_15.dat
# 	wavelet 16: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_16.dat
# 	wavelet 17: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_17.dat
# 	wavelet 18: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_18.dat
# 	wavelet 19: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_19.dat
# 	wavelet 20: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_20.dat
# 	wavelet 21: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_21.dat
# 	wavelet 22: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_22.dat
# 	wavelet 23: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_23.dat
# 	wavelet 24: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_24.dat
# 	wavelet 25: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_25.dat
# 	wavelet 26: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_26.dat
# 	wavelet 27: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_27.dat
# 	wavelet 28: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_28.dat
# 	wavelet 29: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_29.dat
# 	wavelet 30: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_30.dat
# 	wavelet 31: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_31.dat
# 	wavelet 32: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_32.dat
# 	wavelet 33: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_33.dat
# 	wavelet 34: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_34.dat
# 	wavelet 35: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_35.dat
# 	wavelet 36: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_36.dat
# 	wavelet 37: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_37.dat
# 	wavelet 38: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_38.dat
# 	wavelet 39: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_39.dat
# 	wavelet 40: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_40.dat
# 	wavelet 41: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_41.dat
# 	wavelet 42: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_42.dat
# 	wavelet 43: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_43.dat
# 	wavelet 44: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_44.dat
# 	wavelet 45: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_45.dat
# 	wavelet 46: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_46.dat
# 	wavelet 47: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_47.dat
# 	wavelet 48: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_48.dat
# 	wavelet 49: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_49.dat
# 	wavelet 50: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_50.dat
# 	wavelet 51: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_51.dat
# 	wavelet 52: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_52.dat
# 	wavelet 53: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_53.dat
# 	wavelet 54: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_54.dat
# 	wavelet 55: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_55.dat
# 	wavelet 56: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_56.dat
# 	wavelet 57: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_57.dat
# 	wavelet 58: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_58.dat
# 	wavelet 59: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_59.dat
# 	wavelet 60: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_60.dat
# 	wavelet 61: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_61.dat
# 	wavelet 62: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_62.dat
# 	wavelet 63: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_63.dat
# 	wavelet 64: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_64.dat
# 	wavelet 65: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_65.dat
# 	wavelet 66: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_66.dat
# 	wavelet 67: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_67.dat
# 	wavelet 68: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_68.dat
# 	wavelet 69: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_69.dat
# 	wavelet 70: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_70.dat
# 	wavelet 71: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_71.dat
# 	wavelet 72: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_72.dat
# 	wavelet 73: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_73.dat
# 	wavelet 74: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_74.dat
# 	wavelet 75: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_75.dat
# 	wavelet 76: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_76.dat
# 	wavelet 77: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_77.dat
# 	wavelet 78: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_78.dat
# 	wavelet 79: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_79.dat
# 	wavelet 80: ./out_cgg_hard_log3_long_wavefield/wavelet/wavelet_shot_80.dat
# Start simulation for 80 sources. NT: 3000, DT: 0.002...wait
#
# mpirun -np 40 ../den/bin/denise  ./out_cgg_hard_log3_long_wavefield/seis.inp ./out_cgg_hard_log3_long_wavefield/seis_fwi.inp
#
# Done. 66.51232886314392 sec.
#
# Check results in ./out_cgg_hard_log3_long_wavefield/su/

# %%
# print(d.stdout)

# %%
print(src.x[19], src.x[62])
# Out:
# 3975.0 10425.0

# %%
d.verbose = 0    # don't show redundant print outs

if d.DT is None:
    d.DT = 0.002
shots = d.get_shots(keys=['_p'])
# shots = [ld.bandpass(s, fs=1./(d.DT * d.NDT), **par_bp) for s in d.get_shots(keys=['_p'])]
print(f'Read {len(shots)} shots {shots[0].shape} into list')

mpl.rcParams['figure.dpi']= 300
# for ishot in [int(np.floor(x)) for x in np.linspace(0, len(shots)-1, 5)]:
for ishot in [19, 62]:
    print(ishot)
    shot_s = divmax(shots[ishot])
    shot_f = divmax(data_p[ishot, :, ::d.NDT])
#     vis.plot_shot(np.concatenate([np.flip(shot_s, 0), shot_f], axis=0), pclip=0.05)
    vis.plot_compare_stripes(shot_s, shot_f, pclip=0.0125, colorbar=False, dt=d.DT, dx=dx)
mpl.rcParams['figure.dpi']= 100
# Out:
# Read 80 shots (324, 3000) into list
# 19
# 62
